# %%
import pandas as pd
import numpy as np
import datetime, time

import matplotlib.pyplot as plt

# %%
pd.options.display.max_rows = 20
pd.options.display.max_columns = 100
pd.options.display.precision = 4

# %%
def allsatsundays(start_date, end_date):
    day_sat = pd.date_range(start=start_date, end=end_date, 
                         freq='W-SAT').strftime('%Y-%m-%d').tolist()
    day_sun = pd.date_range(start=start_date, end=end_date, 
                         freq='W-SUN').strftime('%Y-%m-%d').tolist()
    days = day_sat+day_sun
    days.sort()
    return days

def get_stock_market_holydays(filename, start_date, end_date):
    df = pd.read_csv(filename)
    kor_days = df['KOR'][df['KOR'].notnull()].values.tolist()
    usa_days = df['USA'][df['USA'].notnull()].values.tolist() # Nan value를 제외한 값을 리스트로 변환

    holydays = allsatsundays(start_date, end_date)
    
    kor_days = sorted(set(kor_days + holydays))
    usa_days = sorted(set(usa_days + holydays))
    
    return kor_days, usa_days

def get_seq_data(filename, holydays):
    df = pd.read_csv(filename)
    df_seq = df[~df['date'].isin(holydays)].copy()
    df_seq.dropna(subset=df.columns[1:], how='all', inplace=True)
    return df_seq

# %%
def classify_data(df, col_name): # column 데이터를 9개로 분류
    col_index = df.columns.tolist()
    for i, col in enumerate(col_name):
        mu = df[col].mean()
        sigma = df[col].std()
        df_min = df[col].min()
        df_max = df[col].max()
        cut_div = [df_min, mu - 3*sigma, mu - 2*sigma, mu - sigma, mu - 0.5*sigma, 
                   mu + 0.5*sigma, mu + sigma, mu + 2*sigma, mu + 3*sigma, df_max ]
        ix = i + col_index.index(col)
        df_new = pd.cut(df[col], cut_div, labels=[1, 2, 3, 4, 5, 6, 7, 8, 9])
        df.insert(ix+1, col+'_class', df_new)
        df[[col, col+'_class']].head()
        
    return df

# %%
def consecutive_count(df_sr, idx): # series, idx: row index 여기서부터 역산으로 추출
    # 매도(-), 매수(+) 연속일 계산
    if idx >= 29: # 최대 20개까지만 확인
        df_sel = df_sr[idx-29:idx+1][::-1]
    else:
        df_sel = df_sr[:idx+1][::-1]
    sr = df_sel.apply(lambda x : 1 if (x > 0) else -1)
    p_sum = 0
    m_sum = 0
    z_sum = 0
    for i, num in enumerate(sr):
        if (num == 0) & (i == z_sum) :
            z_sum += 1
            continue
        elif (num == 1) & (i == p_sum) :
            p_sum += 1
            continue
        elif (num == -1) & (i == m_sum) :
            m_sum += 1
            continue   
        else :
            break

    if p_sum > 0 : 
        return p_sum
    elif m_sum > 0 :
        return -m_sum
    else :
        return z_sum

# %%
def get_dayofweek(df):
    # insert 요일 column: 1: monday, 5: friday
    df['date'] = df['date'].apply(lambda x : datetime.datetime.strptime(x, "%Y-%m-%d"))
    df_dayofweek = df['date'].dt.dayofweek + 1 # 1: monday, 5: Friday
    df.insert(1, 'dayofweek', df_dayofweek)
    
    return df

# %%
def consequtive_days(df, col_names):
    for col in col_names:
        df_temp = df[col].apply(lambda x : 1 if (x > 0) else -1)
        count = []
        for idx in range(len(df_temp)):
            count.append(consecutive_count(df_temp, idx))

        df[col+'_days'] = count  # 매수, 매도 거래 연속일
        
    return df

# %%
def get_weight_ratio(df, investors, investor_sum): # 투자자별 매수 매도 비중 비율
    df['total'] = df[investors_sum].abs().sum(axis=1).to_frame()
    for col in investors:
        df[col+'_ratio'] = df[col]/df['total']*10 # magnify
        
    return df

# %%
def get_change_rate(df, col_names): # get _cr value for each column
    for col in col_names:
        df[col+'_cr'] = (df[col] - df[col].shift(1)) / df[col].shift(1)
    
    return df

# %%
filename = 'https://raw.githubusercontent.com/fasthill/'\
            'factors_affecting_stock_price/main/data/stock_market_holydays/stock_market_holidays.csv'
start_date = '2020-01-01'
end_date = '2022-12-31'

kor_days, usa_days = get_stock_market_holydays(filename, start_date, end_date) # get stock market holydays

# %%
filename = '../data/data_hyunmotor.csv'
df = get_seq_data(filename, kor_days)

# %%
# get day of week
df = get_dayofweek(df)

# %%
# get volumne percentage
df['vol_percent'] = (df['vol'] / df['vol'].sum()) * 100

# %%
df =  df[:-1]
df.tail()
# Out:
#           date  dayofweek   retail  retail_cr  retail_days  foreigner  \
# 919 2022-07-08          5 -20479.0        NaN          NaN    15617.0
# 922 2022-07-11          1 -10749.0        NaN          NaN    11123.0
# 923 2022-07-12          2    868.0        NaN          NaN     3282.0
# 924 2022-07-13          3 -40414.0        NaN          NaN    18096.0
# 925 2022-07-14          4  13810.0        NaN          NaN     9619.0
#
#      foreigner_cr  foreigner_days  institution  institution_cr  \
# 919           NaN             NaN       3853.0             NaN
# 922           NaN             NaN       -719.0             NaN
# 923           NaN             NaN      -3835.0             NaN
# 924           NaN             NaN      22755.0             NaN
# 925           NaN             NaN     -23410.0             NaN
#
#      institution_days  financial  financial_cr  financial_days  invtrust  \
# 919               NaN    -1893.0           NaN             NaN     485.0
# 922               NaN    -3528.0           NaN             NaN    4684.0
# 923               NaN    -4108.0           NaN             NaN    -563.0
# 924               NaN     6795.0           NaN             NaN    6382.0
# 925               NaN   -14077.0           NaN             NaN     949.0
#
#      invtrust_cr  invtrust_days  pension  pension_cr  pension_days  \
# 919          NaN            NaN  -1307.0         NaN           NaN
# 922          NaN            NaN   -354.0         NaN           NaN
# 923          NaN            NaN   3325.0         NaN           NaN
# 924          NaN            NaN   6062.0         NaN           NaN
# 925          NaN            NaN -10782.0         NaN           NaN
#
#      privequity  privequity_cr  privequity_days  bank  bank_cr  bank_days  \
# 919      6348.0            NaN              NaN  -2.0      NaN        NaN
# 922     -3569.0            NaN              NaN   0.0      NaN        NaN
# 923     -3446.0            NaN              NaN  28.0      NaN        NaN
# 924      2539.0            NaN              NaN   0.0      NaN        NaN
# 925       141.0            NaN              NaN  25.0      NaN        NaN
#
#      insurance  insurance_cr  insurance_days  financeetc  financeetc_cr  \
# 919      456.0           NaN             NaN      -234.0            NaN
# 922     2056.0           NaN             NaN        -6.0            NaN
# 923     1048.0           NaN             NaN      -119.0            NaN
# 924      956.0           NaN             NaN        21.0            NaN
# 925      318.0           NaN             NaN        17.0            NaN
#
#      financeetc_days  corporateetc  corporateetc_cr  corporateetc_days  \
# 919              NaN        1017.0              NaN                NaN
# 922              NaN         348.0              NaN                NaN
# 923              NaN        -204.0              NaN                NaN
# 924              NaN        -359.0              NaN                NaN
# 925              NaN          56.0              NaN                NaN
#
#      foreigneretc  foreigneretc_cr  foreigneretc_days  rc1_pcr  rc2_pcr  \
# 919          -8.0              NaN                NaN      NaN      NaN
# 922          -5.0              NaN                NaN      NaN      NaN
# 923        -111.0              NaN                NaN      NaN      NaN
# 924         -79.0              NaN                NaN      NaN      NaN
# 925         -74.0              NaN                NaN      NaN      NaN
#
#      rc3_pcr  rc4_pcr      open      high       low     close  close_cr  \
# 919      NaN      NaN  177500.0  180500.0  177000.0  178000.0      1.71
# 922      NaN      NaN  180000.0  182000.0  179000.0  179000.0      0.56
# 923      NaN      NaN  180000.0  181500.0  177000.0  179000.0      0.00
# 924      NaN      NaN  180000.0  185000.0  178500.0  183500.0      2.51
# 925      NaN      NaN  183000.0  184500.0  180500.0  182500.0     -0.54
#
#           vol  vol_cr  high_time  low_time  vol_percent
# 919  147130.0     NaN        NaN       NaN       0.0922
# 922  119200.0     NaN        NaN       NaN       0.0747
# 923   96440.0     NaN        NaN       NaN       0.0605
# 924  172566.0     NaN        NaN       NaN       0.1082
# 925  142369.0     NaN        NaN       NaN       0.0892

# %%
investors = ['retail', 'foreigner', 'institution', 'financial', 'invtrust', 'pension',
             'privequity', 'bank',  'insurance', 'financeetc', 'corporateetc', 'foreigneretc']
df = classify_data(df, investors) # column data catagorizing

# %%
# get consecutive days with non empty values
df = consequtive_days(df, investors)

# %%
df.head()
# Out:
#         date  dayofweek   retail retail_class  retail_cr  retail_days  \
# 1 2020-01-02          4  21980.0            5        NaN            1
# 2 2020-01-03          5  42651.0            6        NaN            2
# 5 2020-01-06          1   2658.0            5        NaN            3
# 6 2020-01-07          2  13532.0            5        NaN            4
# 7 2020-01-08          3  17848.0            5        NaN            5
#
#    foreigner foreigner_class  foreigner_cr  foreigner_days  institution  \
# 1   -14050.0               5           NaN              -1     -12570.0
# 2   -27939.0               4           NaN              -2     -21214.0
# 5    -1144.0               5           NaN              -3      -5078.0
# 6    -5817.0               5           NaN              -4     -11405.0
# 7    -1415.0               5           NaN              -5     -20996.0
#
#   institution_class  institution_cr  institution_days  financial  \
# 1                 5             NaN                -1    -2598.0
# 2                 4             NaN                -2   -13522.0
# 5                 5             NaN                -3    -9243.0
# 6                 5             NaN                -4    -2705.0
# 7                 4             NaN                -5    -6117.0
#
#   financial_class  financial_cr  financial_days  invtrust invtrust_class  \
# 1               5           NaN              -1    -531.0              5
# 2               4           NaN              -2    -687.0              5
# 5               4           NaN              -3    -563.0              5
# 6               5           NaN              -4   -1738.0              5
# 7               5           NaN              -5   -1014.0              5
#
#    invtrust_cr  invtrust_days  pension pension_class  pension_cr  \
# 1          NaN             -1  -9936.0             4         NaN
# 2          NaN             -2  -3659.0             5         NaN
# 5          NaN             -3   1346.0             5         NaN
# 6          NaN             -4  -6291.0             5         NaN
# 7          NaN             -5 -16321.0             3         NaN
#
#    pension_days  privequity privequity_class  privequity_cr  privequity_days  \
# 1            -1       -22.0                5            NaN               -1
# 2            -2     -1735.0                5            NaN               -2
# 5             1       127.0                5            NaN                1
# 6            -1        81.0                5            NaN                2
# 7            -2      2514.0                6            NaN                3
#
#    bank bank_class  bank_cr  bank_days  insurance insurance_class  \
# 1  50.0          5      NaN          1      355.0               5
# 2 -43.0          5      NaN         -1    -1553.0               5
# 5   0.0          5      NaN         -2     3266.0               7
# 6   3.0          5      NaN          1     -755.0               5
# 7   2.0          5      NaN          2       -3.0               5
#
#    insurance_cr  insurance_days  financeetc financeetc_class  financeetc_cr  \
# 1           NaN               1       112.0                5            NaN
# 2           NaN              -1       -17.0                5            NaN
# 5           NaN               1        -9.0                5            NaN
# 6           NaN              -1         0.0                5            NaN
# 7           NaN              -2       -57.0                5            NaN
#
#    financeetc_days  corporateetc corporateetc_class  corporateetc_cr  \
# 1                1        4600.0                  6              NaN
# 2               -1        6353.0                  7              NaN
# 5               -2        3571.0                  6              NaN
# 6               -3        3741.0                  6              NaN
# 7               -4        4562.0                  6              NaN
#
#    corporateetc_days  foreigneretc foreigneretc_class  foreigneretc_cr  \
# 1                  1          40.0                  5              NaN
# 2                  2         150.0                  5              NaN
# 5                  3          -7.0                  5              NaN
# 6                  4         -51.0                  5              NaN
# 7                  5           0.0                  5              NaN
#
#    foreigneretc_days  rc1_pcr  rc2_pcr  rc3_pcr  rc4_pcr      open      high  \
# 1                  1      NaN      NaN      NaN      NaN  121000.0  121000.0
# 2                  2      NaN      NaN      NaN      NaN  118500.0  119000.0
# 5                 -1      NaN      NaN      NaN      NaN  116000.0  117000.0
# 6                 -2      NaN      NaN      NaN      NaN  116500.0  117000.0
# 7                 -3      NaN      NaN      NaN      NaN  115000.0  115500.0
#
#         low     close  close_cr       vol  vol_cr  high_time  low_time  \
# 1  118000.0  118000.0     -2.07   66205.0     NaN        NaN       NaN
# 2  115000.0  116000.0     -1.69  133657.0     NaN        NaN       NaN
# 5  115500.0  116000.0      0.00   38907.0     NaN        NaN       NaN
# 6  115500.0  115500.0     -0.43   78229.0     NaN        NaN       NaN
# 7  111500.0  112000.0     -3.03  117813.0     NaN        NaN       NaN
#
#    vol_percent
# 1       0.0415
# 2       0.0838
# 5       0.0244
# 6       0.0490
# 7       0.0739

# %%
# get investors amount relative ratio
investors_sum = ['retail', 'foreigner', 'financial', 'invtrust', 'pension',
         'privequity', 'bank',  'insurance', 'financeetc', 'corporateetc', 'foreigneretc']
df = get_weight_ratio(df, investors, investors_sum)

# %%
df.head()
# Out:
#         date  dayofweek   retail retail_class  retail_cr  retail_days  \
# 1 2020-01-02          4  21980.0            5        NaN            1
# 2 2020-01-03          5  42651.0            6        NaN            2
# 5 2020-01-06          1   2658.0            5        NaN            3
# 6 2020-01-07          2  13532.0            5        NaN            4
# 7 2020-01-08          3  17848.0            5        NaN            5
#
#    foreigner foreigner_class  foreigner_cr  foreigner_days  institution  \
# 1   -14050.0               5           NaN              -1     -12570.0
# 2   -27939.0               4           NaN              -2     -21214.0
# 5    -1144.0               5           NaN              -3      -5078.0
# 6    -5817.0               5           NaN              -4     -11405.0
# 7    -1415.0               5           NaN              -5     -20996.0
#
#   institution_class  institution_cr  institution_days  financial  \
# 1                 5             NaN                -1    -2598.0
# 2                 4             NaN                -2   -13522.0
# 5                 5             NaN                -3    -9243.0
# 6                 5             NaN                -4    -2705.0
# 7                 4             NaN                -5    -6117.0
#
#   financial_class  financial_cr  financial_days  invtrust invtrust_class  \
# 1               5           NaN              -1    -531.0              5
# 2               4           NaN              -2    -687.0              5
# 5               4           NaN              -3    -563.0              5
# 6               5           NaN              -4   -1738.0              5
# 7               5           NaN              -5   -1014.0              5
#
#    invtrust_cr  invtrust_days  pension pension_class  pension_cr  \
# 1          NaN             -1  -9936.0             4         NaN
# 2          NaN             -2  -3659.0             5         NaN
# 5          NaN             -3   1346.0             5         NaN
# 6          NaN             -4  -6291.0             5         NaN
# 7          NaN             -5 -16321.0             3         NaN
#
#    pension_days  privequity privequity_class  privequity_cr  privequity_days  \
# 1            -1       -22.0                5            NaN               -1
# 2            -2     -1735.0                5            NaN               -2
# 5             1       127.0                5            NaN                1
# 6            -1        81.0                5            NaN                2
# 7            -2      2514.0                6            NaN                3
#
#    bank bank_class  bank_cr  bank_days  insurance insurance_class  \
# 1  50.0          5      NaN          1      355.0               5
# 2 -43.0          5      NaN         -1    -1553.0               5
# 5   0.0          5      NaN         -2     3266.0               7
# 6   3.0          5      NaN          1     -755.0               5
# 7   2.0          5      NaN          2       -3.0               5
#
#    insurance_cr  insurance_days  financeetc financeetc_class  financeetc_cr  \
# 1           NaN               1       112.0                5            NaN
# 2           NaN              -1       -17.0                5            NaN
# 5           NaN               1        -9.0                5            NaN
# 6           NaN              -1         0.0                5            NaN
# 7           NaN              -2       -57.0                5            NaN
#
#    financeetc_days  corporateetc corporateetc_class  corporateetc_cr  \
# 1                1        4600.0                  6              NaN
# 2               -1        6353.0                  7              NaN
# 5               -2        3571.0                  6              NaN
# 6               -3        3741.0                  6              NaN
# 7               -4        4562.0                  6              NaN
#
#    corporateetc_days  foreigneretc foreigneretc_class  foreigneretc_cr  \
# 1                  1          40.0                  5              NaN
# 2                  2         150.0                  5              NaN
# 5                  3          -7.0                  5              NaN
# 6                  4         -51.0                  5              NaN
# 7                  5           0.0                  5              NaN
#
#    foreigneretc_days  rc1_pcr  rc2_pcr  rc3_pcr  rc4_pcr      open      high  \
# 1                  1      NaN      NaN      NaN      NaN  121000.0  121000.0
# 2                  2      NaN      NaN      NaN      NaN  118500.0  119000.0
# 5                 -1      NaN      NaN      NaN      NaN  116000.0  117000.0
# 6                 -2      NaN      NaN      NaN      NaN  116500.0  117000.0
# 7                 -3      NaN      NaN      NaN      NaN  115000.0  115500.0
#
#         low     close  close_cr       vol  vol_cr  high_time  low_time  \
# 1  118000.0  118000.0     -2.07   66205.0     NaN        NaN       NaN
# 2  115000.0  116000.0     -1.69  133657.0     NaN        NaN       NaN
# 5  115500.0  116000.0      0.00   38907.0     NaN        NaN       NaN
# 6  115500.0  115500.0     -0.43   78229.0     NaN        NaN       NaN
# 7  111500.0  112000.0     -3.03  117813.0     NaN        NaN       NaN
#
#    vol_percent    total  retail_ratio  foreigner_ratio  institution_ratio  \
# 1       0.0415  54274.0        4.0498          -2.5887            -2.3160
# 2       0.0838  98309.0        4.3385          -2.8420            -2.1579
# 5       0.0244  21934.0        1.2118          -0.5216            -2.3151
# 6       0.0490  34714.0        3.8981          -1.6757            -3.2854
# 7       0.0739  49853.0        3.5801          -0.2838            -4.2116
#
#    financial_ratio  invtrust_ratio  pension_ratio  privequity_ratio  \
# 1          -0.4787         -0.0978        -1.8307           -0.0041
# 2          -1.3755         -0.0699        -0.3722           -0.1765
# 5          -4.2140         -0.2567         0.6137            0.0579
# 6          -0.7792         -0.5007        -1.8122            0.0233
# 7          -1.2270         -0.2034        -3.2738            0.5043
#
#    bank_ratio  insurance_ratio  financeetc_ratio  corporateetc_ratio  \
# 1      0.0092           0.0654            0.0206              0.8476
# 2     -0.0044          -0.1580           -0.0017              0.6462
# 5      0.0000           1.4890           -0.0041              1.6281
# 6      0.0009          -0.2175            0.0000              1.0777
# 7      0.0004          -0.0006           -0.0114              0.9151
#
#    foreigneretc_ratio
# 1              0.0074
# 2              0.0153
# 5             -0.0032
# 6             -0.0147
# 7              0.0000

# %%
investors = ['retail', 'foreigner', 'institution', 'financial', 'invtrust', 'pension',
             'privequity', 'bank',  'insurance', 'financeetc', 'corporateetc', 'foreigneretc']
df = get_change_rate(df, investors) # get column change rate data

# %%
df.iloc[0:5, 45:60]
# Out:
#    corporateetc_days  foreigneretc foreigneretc_class  foreigneretc_cr  \
# 1                  1          40.0                  5              NaN
# 2                  2         150.0                  5           2.7500
# 5                  3          -7.0                  5          -1.0467
# 6                  4         -51.0                  5           6.2857
# 7                  5           0.0                  5          -1.0000
#
#    foreigneretc_days  rc1_pcr  rc2_pcr  rc3_pcr  rc4_pcr      open      high  \
# 1                  1      NaN      NaN      NaN      NaN  121000.0  121000.0
# 2                  2      NaN      NaN      NaN      NaN  118500.0  119000.0
# 5                 -1      NaN      NaN      NaN      NaN  116000.0  117000.0
# 6                 -2      NaN      NaN      NaN      NaN  116500.0  117000.0
# 7                 -3      NaN      NaN      NaN      NaN  115000.0  115500.0
#
#         low     close  close_cr       vol
# 1  118000.0  118000.0     -2.07   66205.0
# 2  115000.0  116000.0     -1.69  133657.0
# 5  115500.0  116000.0      0.00   38907.0
# 6  115500.0  115500.0     -0.43   78229.0
# 7  111500.0  112000.0     -3.03  117813.0

# %%
import datetime
import time
from datetime import date

import pandas as pd
import numpy as np

import os, sys

# %%
predict_directory = '../data/data_for_ml/predict/'
df_o = pd.read_pickle(predict_directory + '0_df_common.pkl')

# %%
df_amore_company
0_df_common
# Out:
#   Cell In[60], line 2
#     0_df_common
#      ^
# SyntaxError: invalid decimal literal

# %%
df_o
# Out:
#            bond_kor_10_cr  bond_kor_10_cr_2 bond_kor_2_cr  bond_kor_2_cr_2
# date
# 2021-12-20            NaN               NaN           NaN              NaN  \
# 2021-12-21         -2.04%          -2.04461        -0.60%         -0.59880
# 2021-12-22         -0.62%          -2.64870        -0.90%         -1.49701
# 2021-12-23          2.53%           1.89753         1.16%          0.24096
# 2021-12-24          3.12%           5.72792         2.70%          3.89058
# ...                   ...               ...           ...              ...
# 2023-06-16         +1.26%           2.93460        +1.91%          3.62869
# 2023-06-19         -0.71%           0.54990        -1.38%          0.49793
# 2023-06-20         -0.68%          -0.68343        +0.19%          0.19263
# 2023-06-21         +0.22%          -0.46473        -0.99%         -0.79802
# 2023-06-22         -0.66%          -0.44041        +0.97%         -0.02746
#
# ...

# %%
def string_to_num(df):
    df.replace('%', '', regex=True, inplace=True)
    return df.apply(pd.to_numeric)

# %%
df_o.dropna(inplace=True)

# %%
df_o
# Out:
#             bond_kor_10_cr  bond_kor_10_cr_2  bond_kor_2_cr  bond_kor_2_cr_2
# date
# 2021-12-30           -0.73         -1.446655          -0.36          0.29922  \
# 2022-01-03            3.12          2.367942          -0.24         -0.59453
# 2022-01-04            6.80          3.015521           2.40          2.27273
# 2022-01-05           -0.39          6.390805           0.29          2.69461
# 2022-01-06            2.64          2.238485           4.55          4.85380
# ...                    ...               ...            ...              ...
# 2023-06-15            1.65          1.762731           1.69          0.80870
# 2023-06-16            1.26          2.934600           1.91          3.62869
# 2023-06-19           -0.71          0.549904          -1.38          0.49793
# 2023-06-21            0.22         -0.464735          -0.99         -0.79802
# 2023-06-22           -0.66         -0.440407           0.97         -0.02746
#
# ...

# %%
string_to_num(df_o)
# Out:
#             bond_kor_10_cr  bond_kor_10_cr_2  bond_kor_2_cr  bond_kor_2_cr_2
# date
# 2021-12-30           -0.73         -1.446655          -0.36         0.299222  \
# 2022-01-03            3.12          2.367942          -0.24        -0.594530
# 2022-01-04            6.80          3.015521           2.40         2.272727
# 2022-01-05           -0.39          6.390805           0.29         2.694611
# 2022-01-06            2.64          2.238485           4.55         4.853801
# ...                    ...               ...            ...              ...
# 2023-06-15            1.65          1.762731           1.69         0.808701
# 2023-06-16            1.26          2.934600           1.91         3.628692
# 2023-06-19           -0.71          0.549904          -1.38         0.497925
# 2023-06-21            0.22         -0.464735          -0.99        -0.798019
# 2023-06-22           -0.66         -0.440407           0.97        -0.027465
#
# ...

# %%
df_o['krw_cr'].apply(lambda x: f'{x:.3f}')

# %%
df_o = df_o.apply(pd.to_numeric)

# %%
df_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, 2021-12-30 to 2023-06-22
# Data columns (total 74 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bond_kor_10_cr    349 non-null    float64
#  1   bond_kor_10_cr_2  349 non-null    float64
#  2   bond_kor_2_cr     349 non-null    float64
#  3   bond_kor_2_cr_2   349 non-null    float64
#  4   kosdaq_cr         349 non-null    float64
#  5   kosdaq_cr_2       349 non-null    float64
#  6   kospi_cr          349 non-null    float64
#  7   kospi_cr_2        349 non-null    float64
#  8   krw_cr            349 non-null    float64
#  9   krw_cr_2          349 non-null    float64
#  10  dji_cr            349 non-null    float64
#  11  dji_cr_2          349 non-null    float64
#  12  dji_f_cr          349 non-null    float64
#  13  dji_f_cr_2        349 non-null    float64
#  14  dxy_cr            349 non-null    float64
#  15  dxy_cr_2          349 non-null    float64
# ...

# %%
df_o.apply(lambda x: float(f'{x:.5f}'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df_o.apply(lambda x: float(f'{x:.5f}'))
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:9428, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9417 from pandas.core.apply import frame_apply
#    9419 op = frame_apply(
#    9420     self,
#    9421     func=func,
#    (...)
#    9426     kwargs=kwargs,
#    9427 )
# -> 9428 return op.apply().__finalize__(self, method="apply")
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# ...

# %%
dff = df_o.apply(pd.to_numeric)

# %%
pp = list(df_o.columns)

# %%
ddd = pd.DataFrame()

# %%
for nn in pp:
    ddd[nn] = df_o[nn].apply(lambda x: f'{x:.5f}')

# %%
ddd
# Out:
#            bond_kor_10_cr bond_kor_10_cr_2 bond_kor_2_cr bond_kor_2_cr_2
# date
# 2021-12-30       -0.73000         -1.44665      -0.36000         0.29922  \
# 2022-01-03        3.12000          2.36794      -0.24000        -0.59453
# 2022-01-04        6.80000          3.01552       2.40000         2.27273
# 2022-01-05       -0.39000          6.39080       0.29000         2.69461
# 2022-01-06        2.64000          2.23848       4.55000         4.85380
# ...                   ...              ...           ...             ...
# 2023-06-15        1.65000          1.76273       1.69000         0.80870
# 2023-06-16        1.26000          2.93460       1.91000         3.62869
# 2023-06-19       -0.71000          0.54990      -1.38000         0.49793
# 2023-06-21        0.22000         -0.46473      -0.99000        -0.79802
# 2023-06-22       -0.66000         -0.44041       0.97000        -0.02746
#
#            kosdaq_cr kosdaq_cr_2  kospi_cr kospi_cr_2    krw_cr  krw_cr_2
# date
# ...

# %%
dff.info()

# %%
def form_decimal(x):
    return f'{x:.5f}'

# %%
form_decimal(3.2)
# Out:
# '3.20000'

# %%
df_o['bond_kor_2_cr_2'] = df_o['bond_kor_2_cr_2'].apply(lambda x: float(f'{x:.5f}'))

# %%
df_o.apply(lambda x: float(f'{x:.5f}'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df_o.apply(lambda x: float(f'{x:.5f}'))
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:9428, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9417 from pandas.core.apply import frame_apply
#    9419 op = frame_apply(
#    9420     self,
#    9421     func=func,
#    (...)
#    9426     kwargs=kwargs,
#    9427 )
# -> 9428 return op.apply().__finalize__(self, method="apply")
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# ...

# %%
for key, val in code.items():
    globals()['df_{}_combine'.format(val[1])] = string_to_num(globals()['df_{}_combine'.format(val[1])])

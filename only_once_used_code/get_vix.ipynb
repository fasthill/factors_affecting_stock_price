# %% [markdown]
# ### 최초 한번 실행 과거 데이터 추출용

# %%
from selenium import webdriver as wd
from bs4 import BeautifulSoup as bs
import requests
import datetime, time
from datetime import date

import pandas as pd
import re
import os, sys

# %%
today = datetime.date.today()
today = today.strftime('%Y%m%d')

# %%
# url = 'https://finance.yahoo.com/quote/%5EVIX/history?p=%5EVIX'
# # res = requests.get(url)

# headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) \
#            AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
# res = requests.get(url, headers=headers)
# soup = bs(res.text, 'html.parser')
# df = pd.read_html(res.text)

# %%
filename = '{}{}.csv'.format('data/vix_', today)

url = 'https://finance.yahoo.com/quote/%5EVIX/history?p=%5EVIX'
# res = requests.get(url)

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) \
           AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
res = requests.get(url, headers=headers)
df = pd.read_html(res.text)

# soup = bs(res.text, 'html.parser')
# tbl = soup.select("#Col1-1-HistoricalDataTable-Proxy > section > div.Pb\(10px\).Ovx\(a\).W\(100\%\) > table")
# # tbl = soup.find("table",{"class":"W(100%) M(0)", 'data-test':"historical-prices" })

# df = pd.read_html(str(tbl))

df[0].to_csv(filename, index=False)

# %%
df[0]
# Out:
#                                                   Date  \
# 0                                         Jun 22, 2022
# 1                                         Jun 21, 2022
# 2                                         Jun 17, 2022
# 3                                         Jun 16, 2022
# 4                                         Jun 15, 2022
# ..                                                 ...
# 96                                        Feb 02, 2022
# 97                                        Feb 01, 2022
# 98                                        Jan 31, 2022
# 99                                        Jan 28, 2022
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                                31.45
# 1                                                30.63
# 2                                                32.84
# 3                                                30.35
# ...

# %%
table_GDP = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States', match='Nominal GDP')

# %%
table_GDP[0]
# Out:
#                                          No.  \
# 0                                          1
# 1  *Percentages from CIA World Factbook[133]
#
#                              Country/Economy  \
# 0                              United States
# 1  *Percentages from CIA World Factbook[133]
#
#                                  Nominal GDP  \
# 0                                   18624450
# 1  *Percentages from CIA World Factbook[133]
#
#                                        Agri.  \
# 0                                  204868.95
# 1  *Percentages from CIA World Factbook[133]
#
#                                       Indus.  \
# 0                                  3613143.3
# 1  *Percentages from CIA World Factbook[133]
#
#                                        Serv.
# 0                                14806437.75
# 1  *Percentages from CIA World Factbook[133]

# %%
table_GDP = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States')

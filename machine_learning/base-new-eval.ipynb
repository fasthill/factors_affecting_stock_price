# %% [markdown]
# <a href="https://colab.research.google.com/github/fasthill/ML-DL-study-alone/blob/main/5-1%20%EA%B2%B0%EC%A0%95%20%ED%8A%B8%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analyse from LightGBM
#
# ### train, val, test data로 분류

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/5-1.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
import datetime
import os, re

# %%
from xgboost import XGBClassifier
import xgboost
from lightgbm import LGBMClassifier
import lightgbm
import joblib

# %%
from skopt import BayesSearchCV
# parameter ranges are specified by one of below
from skopt.space import Real, Categorical, Integer

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier, SGDRegressor
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import make_scorer

from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import pickle

# write list, dictionary to pickle
def save_to_pickle(path, filename):
    open_file = open(path, "wb")
    pickle.dump(filename, open_file)
    open_file.close()

# read list, dictionary from pickle
def load_from_pickle(path):
    open_file = open(path, "rb")
    loaded_file = pickle.load(open_file)
    open_file.close()
    return loaded_file

# %%
import csv

# write list, dictionary to csv
# path = './xxx/', my_dict = filename

def save_dict_to_csv(path, my_dict):
    fields=my_dict.keys()
    values = my_dict.values()
    pd.DataFrame([fields, values], index=['parameter','value']).T.to_csv(path)
#     df = pd.DataFrame.from_dict(my_dict, orient='index') 
#     df.to_csv (path, index=False, header=True)  
    
def save_list_to_csv(path, my_list):
    df = pd.DataFrame(my_list, columns=['columns'])
    df.to_csv (path, index=False, header=True) 
    
# def load_dict_from_csv(path):
#     df = pd.read_csv(path, header=None)
#     my_dict = df.to_dict()
#     return my_dict

# %%
def predict_p(test_target, y_predict_list): 
    ps = precision_score(test_target, y_predict_list)
    rs = recall_score(test_target, y_predict_list)
    fs = f1_score(test_target, y_predict_list)
    roc = roc_auc_score(test_target, y_predict_list)
    collect_list = [ps, rs, fs, roc]
    return collect_list

# %%
def make_df_from_estimator(estimator, num):
    df_t = pd.DataFrame.from_dict(estimator, orient='index')
    df_t.columns = [f'iter_{num}']
    df_t.index.name = 'parameter'
    return df_t

# %%
def calc_results(lgbm, model, train_scaled, val_scaled, test_scaled, train_target, val_target, test_target):
# model = lgbmgs.best_estimator_  # 최적의 파라미터로 모델 생성
    y_predict_train = model.predict(train_scaled)
    y_predict_val = model.predict(val_scaled)
    y_predict_test = model.predict(test_scaled)
    result_dict= {}
    result_dict['best_score'] = lgbm.best_score_ 
    result_dict['best_index'] = lgbm.best_index_
    result_dict['acc_train'] = model.score(train_scaled, train_target)
    result_dict['acc_val'] = model.score(val_scaled, val_target)
    result_dict['acc_test'] = model.score(test_scaled, test_target)
    result_dict['train_precision'] = precision_score(train_target, y_predict_train)
    cm = confusion_matrix(train_target, y_predict_train)
    result_dict['train_tn'] = cm[0,0]
    result_dict['train_fp'] = cm[0,1]
    result_dict['train_fn'] = cm[1,0]
    result_dict['train_tp'] = cm[1,1]
    result_dict['val_precision'] = precision_score(val_target, y_predict_val)
    cm = confusion_matrix(val_target, y_predict_val)
    result_dict['val_tn'] = cm[0,0]
    result_dict['val_fp'] = cm[0,1]
    result_dict['val_fn'] = cm[1,0]
    result_dict['val_tp'] = cm[1,1]
    result_dict['test_precision'] = precision_score(test_target, y_predict_test)
    result_dict['recall'] = recall_score(test_target, y_predict_test)
    result_dict['f1score'] = f1_score(test_target, y_predict_test)
    result_dict['roc'] = roc_auc_score(test_target, y_predict_test)
    cm = confusion_matrix(test_target, y_predict_test)
    result_dict['test_tn'] = cm[0,0]
    result_dict['test_fp'] = cm[0,1]
    result_dict['test_fn'] = cm[1,0]
    result_dict['test_tp'] = cm[1,1]
#     result_dict['precision_neg'] = cm[0,0] / (cm[0,0] + cm[1,0])
    return result_dict

# %%
def save_best_results(com_name, model, scaler, columns, df_base):
    joblib.dump(model, f'{directory_for_model}{com_name}/best_model.pkl') # estimaor 저장
    joblib.dump(scaler, f'{directory_for_model}{com_name}/best_scaler.pkl') # scaler 저장
    save_to_pickle(f'{directory_for_model}{com_name}/best_model_p.pkl', model)
    save_to_pickle(f'{directory_for_model}{com_name}/best_scaler_p.pkl', scaler)
    save_to_pickle(f'{directory_for_model}{com_name}/best_columns.pkl', new_col)
    save_list_to_csv(f'{directory_for_model}{com_name}/best_columns.csv', new_col)
    df_base.to_pickle(f'{directory_for_model}{com_name}/best_result.pkl')
    return

# %%
def add_dict(*dicts):
    dsum = {}
    d_k = []
    d_v = []
    for dic in dicts:
        d_k.extend(list(dic.keys()))  # sum keys list
        d_v.extend(list(dic.values()))  # sum values list
    for i in range(len(d_k)):
        dsum[d_k[i]] = d_v[i]
    return dsum

# %%
def df_combine_sorted(df_base_l, df_params_l):
    o_num = list(df_base_l.index).index('best_score')
    df1 = df_base.iloc[:o_num, :]
    df2 = df_base.iloc[o_num:, :]
    df3 = pd.concat([df1, df_params_l], axis=0)
    df3.sort_index(axis=0, inplace=True)
    df_sorted = pd.concat([df3, df2], axis=0)
    return df_sorted

# %%
import sys, os

module_path = os.path.abspath(os.path.join('..')) # 현재 폴더로 이동
if module_path+"\\data\\base_data\\common_data" not in sys.path:
    sys.path.append(module_path+"\\data\\base_data\\common_data") #  공통으로 사용하는 각종 리스트, 코드 등 
    
import common_data as cd

# %%
def df_style(df_s, row_index_l):
#     xin = [list(df_s.index).index(x) for x in row_index_l]
    xin = []
    for x in list(df_s.index):
        try:
            if x in row_index_l:
                xin.append(list(df_s.index).index(x))
        except:
            pass
    return df_s.reset_index('parameter').style.apply(
        lambda x: ['background-color: yellow' if row in xin else '' for row in range(len(df_s.index))], axis=0)

# %%
code = cd.code_all # 전체 회사 코드
code =  {'005930' : ['삼성전자', 'sec']}

# %%
col_inv1 = ['retail_1', 'foreigner_1', 'institution_1', 'financial_1', 'invtrust_1', 'pension_1', 
#             'privequity_1', 'bank_1', 'insurance_1', 'financeetc_1', 'corporateetc_1', 
            'privequity_1',  'insurance_1', 'corporateetc_1', # bank_1, 'financeetc_1 제외
            'foreigneretc_1']
col_inv2 = ['retail_2', 'foreigner_2', 'institution_2', 'financial_2', 'invtrust_2', 'pension_2',
#             'privequity_2', 'bank_2', 'insurance_2', 'financeetc_2', 'corporateetc_2', 
            'privequity_2', 'insurance_2', 'corporateetc_2', # bank_2, 'financeetc_2 제외
            'foreigneretc_2']
col_his1 = ['open_1', 'high_1', 'low_1', 'close_1', 'vol_1']
col_his2 = ['open_2', 'high_2', 'low_2', 'close_2', 'vol_2']
col_cr = ['weekday', 'cr_00', 'cr_05', 'cr_10', 'cr_15', 'cr_20']
col_common1 = ["dji_cr", "dji_f_cr", "dxy_cr", "ixic_f_cr", "bond_kor_10_cr", "bond_kor_2_cr", "kosdaq_cr", "kospi_cr", 
         "krw_cr", "ixic_cr", "spx_f_cr", "sox_cr", "spx_cr", "bond_usa_10_cr", "bond_usa_2_cr", "bond_usa_3m_cr", 
         "vix_cr", "wti_cr", "spsy_cr", "spny_cr", "spxhc_cr", "splrcd_cr", "splrci_cr", "splrcu_cr", "splrcs_cr",
         "splrct_cr", "splrcl_cr", "splrcm_cr", "ixbk_cr", "ixfn_cr", "ixid_cr", "ixis_cr", "ixk_cr", "ixtr_cr",
         "ixut_cr", "nbi_cr", "bkx_cr"]
col_common2 = ["dji_cr_2", "dji_f_cr_2", "dxy_cr_2", "ixic_f_cr_2", "bond_kor_10_cr_2", "bond_kor_2_cr_2", "kosdaq_cr_2", "kospi_cr_2",
         "krw_cr_2", "ixic_cr_2", "spx_f_cr_2", "sox_cr_2", "spx_cr_2", "bond_usa_10_cr_2", "bond_usa_2_cr_2", "bond_usa_3m_cr_2",
         "vix_cr_2", "wti_cr_2", "spsy_cr_2", "spny_cr_2", "spxhc_cr_2", "splrcd_cr_2", "splrci_cr_2", "splrcu_cr_2",
         "splrcs_cr_2", "splrct_cr_2", "splrcl_cr_2", "splrcm_cr_2", "ixbk_cr_2", "ixfn_cr_2", "ixid_cr_2",
         "ixis_cr_2", "ixk_cr_2", "ixtr_cr_2", "ixut_cr_2", "nbi_cr_2", "bkx_cr_2"]
col_futures = ['ixic_f_cr', 'ixic_f_cr_2', 'spx_f_cr', 'spx_f_cr_2', 'dji_f_cr', 'dji_f_cr_2',
           'wti_cr','wti_cr_2', 'dxy_cr', 'dxy_cr_2', 'bond_usa_10_cr', 'bond_usa_10_cr_2' ]
column_o = col_inv1 + col_common1 + col_his1 + col_inv2 + col_common2 + col_his2 + col_cr

col_except_futures = [item for item in column_o if item not in col_futures]

new_col = col_except_futures.copy()

# bank, financeetc는 결측치가 많아서 사용하지 않음.
# df.drop(['bank_1', 'bank_2', 'financeetc_1', 'financeetc_2'], axis=1, inplace=True)   

# col_futures : futures는 당일 종료가 되지 않는 data이므로 제외

# %%
# 최초의 empty df 생성
df_base = pd.DataFrame(pd.Series([],dtype=pd.StringDtype(), name='parameter')).set_index('parameter')
df_params = pd.DataFrame(pd.Series([],dtype=pd.StringDtype(), name='parameter')).set_index('parameter')
iter = 0

# %%
#### 신규 분석 데이터는 아래 것으로 사용

com_name = list(code.values())[0][1]

directory_for_ml = '../data/data_for_ml/predict/'
fname = f'df_{com_name}_combine.pkl'
f_name = directory_for_ml + fname
df_o = pd.read_pickle(f_name) 
df_o = df_o.iloc[:-1] # /predict/를 사용할 경우 마지막 prediction data 제외

# %%
len(df_o)
# Out:
# 319

# %%
train_start_index = list(df_o.index).index(datetime.date(2022, 3, 2))
train_end_index = list(df_o.index).index(datetime.date(2023, 3, 31))
val_end_index = list(df_o.index).index(datetime.date(2023, 4, 28))

# %%
df_o_train = df_o.iloc[train_start_index:train_end_index+1]
df_o_val = df_o.iloc[train_end_index+1:val_end_index+1]
df_o_test = df_o.iloc[val_end_index+1:]

# %%
df = df_o_train[new_col]
train_input = df.iloc[:, :-5]
train_target = df.iloc[:, -5]

df = df_o_val[new_col]
val_input = df.iloc[:, :-5]
val_target = df.iloc[:, -5]

df = df_o_test[new_col]
test_input = df.iloc[:, :-5]
test_target = df.iloc[:, -5]

# %%
scaler = None
scaler = StandardScaler()
scaler.fit(train_input)
train_scaled = scaler.transform(train_input)
val_scaled = scaler.transform(val_input)
test_scaled = scaler.transform(test_input)

# %%
# 반복 작업시 여기서 부터 진행 (feature importance로 선정된 새로운 column으로)

df = df_o[new_col]  # 새롭게 선정된 column으로 진행

# train, val,: 8, test: 2
split_ratio = 0.8
split_n = int(len(df)*split_ratio)

test_interval = int((len(df) - split_n)/3)
data = df.iloc[:split_n, :-5]
target = df.iloc[:split_n, -5]
test_input = df.iloc[split_n:, :-5]
test_target = df.iloc[split_n:, -5]
test_input1 = df.iloc[split_n:split_n+test_interval, :-5]
test_input2 = df.iloc[split_n+test_interval: split_n+test_interval*2, :-5]
test_input3 = df.iloc[split_n+test_interval*2:, :-5]
test_target1 = df.iloc[split_n:split_n+test_interval, -5]
test_target2 = df.iloc[split_n+test_interval: split_n+test_interval*2, -5]
test_target3 = df.iloc[split_n+test_interval*2:, -5]

train_input, val_input, train_target, val_target = \
     train_test_split(data, target, random_state=42, test_size=0.2, stratify=target)

scaler = None
scaler = StandardScaler()
scaler.fit(train_input)
train_scaled = scaler.transform(train_input)
val_scaled = scaler.transform(val_input)
test_scaled = scaler.transform(test_input)
test_scaled1 = scaler.transform(test_input1)
test_scaled2 = scaler.transform(test_input2)
test_scaled3 = scaler.transform(test_input3)

# %%
search_space = {
    'boosting_type' : ['gbdt', 'dart', ],# ['gbdt', 'dart', 'goss'],
    'learning_rate': (0.0001, 0.004, 'log-uniform'),
    'num_leaves': (3, 20),      
    'max_depth': (0, 50), #[-1], #(0, 50),
    'min_child_samples': (5, 40),
#     'min_child_weight': (0.001, 10.0), # 값을 변동시 같은 값이 최적값으로 선정되더라고 precision이 틀림. 반드시 값을 바꾸면서 진행해야 함.
#     'min_split_loss': (0, 5), 
    'max_bin': (100, 1000), # 사용시 0.75%로 올라감 default: 255
#     'max_cat_threshold' : (1, 100),
    'subsample': (0.005, 1.0, 'uniform'), # == bagging_fraction
#     'subsample_freq': (1, 10), # mobis에서 적용시 값이 많이 올라감. default:0
    'colsample_bytree': (0.5, 1.0, 'uniform'),
    'subsample_for_bin': (100000, 500000),
    'scale_pos_weight' : (0.2, 2.0, 'uniform'),
#     'scale_pos_weight': np.arange(0.2, 2, 0.1) ,
    'n_estimators': (700, 5000),
    'reg_alpha' : (0.0, 4.0, 'uniform'), # =='lambda_l1': [0, 5], # default 0
    'reg_lambda' : (0.0, 4.0, 'uniform'), # == lambda_l2': [0, 5], #default 0    
#     'reg_alpha' : np.arange(0, 4, 0.1),
#     'reg_lambda' : np.arange(0, 4, 0.1),
    'force_col_wise': ['true'], 
    'importance_type': ['split'], # ['gain'], default: split
    'boost_from_average' : [True, False],
    'objective': ['binary'],
    'metric': ['binary_logloss'],
}

params_space = search_space.copy() # for Bayesian Optimization

# %% [markdown]
# ## BayesSearchCV

# %%
param_grid = {
    'cv' : 5,  # usually 5 or 10, default: 3
#     'cv' : None,
#     'scoring' : None,
#     'scoring' : 'f1',
#     'scoring' : 'roc_auc',
    'scoring' : 'precision',
#     'scoring' : 'average_precision',
#     'scoring' : 'accuracy',
    'num_col' : len(new_col),
    'iterations' : 10,  # default : 50, number of parameter settings.
    # The number of parameter settings that are tried is given by n_iter.
             }

# %%
# directory_for_model = '../../data/data_for_ml/model/model/0. test/'
directory_for_model = '../data/data_for_ml/model/model/'

# %%
# directory가 없으면 만드는 과정
# if not os.path.exists(com_name):
#     os.makedirs(com_name)
if not os.path.exists(directory_for_model+com_name):
    os.makedirs(directory_for_model+com_name)

iter = iter + 1

lgbm = None
lgbmBS = None
gsbs = 'bs'

lgbmBS = BayesSearchCV( estimator = lightgbm.LGBMClassifier(verbose=0, random_state=42),
                       search_spaces = params_space,
                       scoring = param_grid['scoring'],
                       cv = StratifiedKFold( n_splits=param_grid['cv'],
                                             shuffle=True,
                                             random_state=42 ),
                       n_jobs = -1, # 자동 검색 적용
                       n_iter = param_grid['iterations'],   
                       verbose = 0, refit = True, random_state = 42 
                      )

print("*** after lgbm BS ******")
# lgbmBS.fit(train_scaled, train_target, eval_metric = 'logloss') 
# lgbmBS.fit(train_scaled, train_target, early_stopping_rounds=200, eval_metric='logloss', eval_set=[(val_input, val_target)])
lgbmBS.fit(train_scaled, train_target, eval_metric='logloss', eval_set=[(val_input, val_target)])

# save model
stamp = datetime.datetime.today().isoformat() # 파일명 끝에 생성날짜 시간 추가
dt = re.sub(r'[-:T]', '', stamp[5:16])
dt = f'{dt[:4]}_{dt[4:]}'

df_estimator = make_df_from_estimator(lgbmBS.best_estimator_.get_params(), iter)
df_estimator.sort_index(inplace=True) # alphabet 순으로 보기 편하게

# metrics accuracy,,,, 3단계 precision 등까지. dictionary
result_dict = calc_results(lgbmBS, lgbmBS.best_estimator_, 
                           train_scaled, val_scaled, test_scaled,  
                           train_target, val_target, test_target,
                          )

df_grid = make_df_from_estimator(param_grid, iter) # gridcv parameter
df_grid.sort_index(inplace=True) # alphabet 순으로 보기 편하게
df_result = make_df_from_estimator(result_dict, iter)  # dict 를 df로
df_concat = pd.concat([df_grid, df_estimator, df_result])

df_base = pd.merge(df_base,df_concat, how='outer', left_index=True, right_index=True)

# val_test = df_concat.loc['acc_val'].iloc[0]
# acc_test = df_concat.loc['acc_test'].iloc[0]
# precision = df_concat.loc['test_precision'].iloc[0]
# f1score = df_concat.loc['f1score'].iloc[0]

params_search = add_dict(param_grid, search_space)
df_params_search = make_df_from_estimator(params_search, iter)
df_params = pd.merge(df_params,df_params_search, how='outer', left_index=True, right_index=True)
  
print("******* No.{} BS Process is Done! ********".format(iter))
    
print("**** End of BayesSearchCV Process ****")
# Out:
# *** after lgbm BS ******
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.688519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.688507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.688491
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.688482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.688467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.688458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.68846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.688449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.688437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.688438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.688423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.688423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.688415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.688401
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.688385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.688369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.688374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.688365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.688363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.688364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.688368
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.688178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.688167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.688413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.688409
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.688398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.688386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.688388
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.688391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.688381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's binary_logloss: 0.688361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.688365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's binary_logloss: 0.688354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.688344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.688333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's binary_logloss: 0.688316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's binary_logloss: 0.688317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's binary_logloss: 0.688675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.688666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.688655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.68866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.688665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.688656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's binary_logloss: 0.688645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.688628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's binary_logloss: 0.688634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.688615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's binary_logloss: 0.688623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.688627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.688618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's binary_logloss: 0.688622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's binary_logloss: 0.688622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's binary_logloss: 0.688626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's binary_logloss: 0.688617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's binary_logloss: 0.688623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's binary_logloss: 0.688604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's binary_logloss: 0.688594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's binary_logloss: 0.688582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's binary_logloss: 0.688587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's binary_logloss: 0.688571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's binary_logloss: 0.68858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's binary_logloss: 0.688563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's binary_logloss: 0.688869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's binary_logloss: 0.689187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's binary_logloss: 0.689194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's binary_logloss: 0.689181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's binary_logloss: 0.689182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's binary_logloss: 0.689167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's binary_logloss: 0.689147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's binary_logloss: 0.689153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's binary_logloss: 0.689159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's binary_logloss: 0.68915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's binary_logloss: 0.689139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's binary_logloss: 0.689146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's binary_logloss: 0.689133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's binary_logloss: 0.689139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's binary_logloss: 0.689126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's binary_logloss: 0.689129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's binary_logloss: 0.689134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's binary_logloss: 0.689137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's binary_logloss: 0.689117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's binary_logloss: 0.6891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's binary_logloss: 0.689105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's binary_logloss: 0.689093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's binary_logloss: 0.689097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's binary_logloss: 0.689103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's binary_logloss: 0.68909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's binary_logloss: 0.689095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's binary_logloss: 0.6891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's binary_logloss: 0.689107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's binary_logloss: 0.689113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's binary_logloss: 0.689096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's binary_logloss: 0.689084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's binary_logloss: 0.689064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's binary_logloss: 0.689048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's binary_logloss: 0.689038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's binary_logloss: 0.689021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's binary_logloss: 0.689026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's binary_logloss: 0.689031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's binary_logloss: 0.689037
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's binary_logloss: 0.689024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's binary_logloss: 0.689012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's binary_logloss: 0.689017
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's binary_logloss: 0.689021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's binary_logloss: 0.689027
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's binary_logloss: 0.689278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's binary_logloss: 0.689284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's binary_logloss: 0.689292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's binary_logloss: 0.689299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's binary_logloss: 0.689282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's binary_logloss: 0.689288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's binary_logloss: 0.689295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's binary_logloss: 0.689283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's binary_logloss: 0.689291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's binary_logloss: 0.689295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's binary_logloss: 0.689283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's binary_logloss: 0.689288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's binary_logloss: 0.689294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's binary_logloss: 0.689298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's binary_logloss: 0.689278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's binary_logloss: 0.689283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's binary_logloss: 0.689289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's binary_logloss: 0.689454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's binary_logloss: 0.689457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's binary_logloss: 0.689433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's binary_logloss: 0.689439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's binary_logloss: 0.689442
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's binary_logloss: 0.689426
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's binary_logloss: 0.6894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's binary_logloss: 0.68955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's binary_logloss: 0.689526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's binary_logloss: 0.689532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's binary_logloss: 0.689513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's binary_logloss: 0.68952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's binary_logloss: 0.689496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's binary_logloss: 0.689503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's binary_logloss: 0.689511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's binary_logloss: 0.689517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's binary_logloss: 0.689522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's binary_logloss: 0.689509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's binary_logloss: 0.689496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's binary_logloss: 0.689486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's binary_logloss: 0.689462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's binary_logloss: 0.68945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's binary_logloss: 0.689457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's binary_logloss: 0.689452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's binary_logloss: 0.689458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's binary_logloss: 0.689464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's binary_logloss: 0.689447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's binary_logloss: 0.689427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's binary_logloss: 0.689435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's binary_logloss: 0.689443
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's binary_logloss: 0.689449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's binary_logloss: 0.689458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's binary_logloss: 0.689465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's binary_logloss: 0.68947
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's binary_logloss: 0.689478
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's binary_logloss: 0.689484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's binary_logloss: 0.689489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's binary_logloss: 0.689472
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's binary_logloss: 0.689476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's binary_logloss: 0.689464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's binary_logloss: 0.689582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's binary_logloss: 0.689569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's binary_logloss: 0.689705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's binary_logloss: 0.68971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's binary_logloss: 0.689691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's binary_logloss: 0.689678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's binary_logloss: 0.689662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's binary_logloss: 0.689668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	valid_0's binary_logloss: 0.689674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's binary_logloss: 0.68965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's binary_logloss: 0.689637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's binary_logloss: 0.689644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's binary_logloss: 0.689619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's binary_logloss: 0.689607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's binary_logloss: 0.689615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's binary_logloss: 0.68959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's binary_logloss: 0.689577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's binary_logloss: 0.689586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid_0's binary_logloss: 0.689594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's binary_logloss: 0.689781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's binary_logloss: 0.689762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's binary_logloss: 0.689769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's binary_logloss: 0.689755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's binary_logloss: 0.689763
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's binary_logloss: 0.68977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's binary_logloss: 0.689756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's binary_logloss: 0.689763
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's binary_logloss: 0.689752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's binary_logloss: 0.689758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's binary_logloss: 0.689745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid_0's binary_logloss: 0.689754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's binary_logloss: 0.689741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's binary_logloss: 0.689749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid_0's binary_logloss: 0.689734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's binary_logloss: 0.68974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's binary_logloss: 0.689746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's binary_logloss: 0.689753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's binary_logloss: 0.689759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's binary_logloss: 0.689765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid_0's binary_logloss: 0.68977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid_0's binary_logloss: 0.689777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's binary_logloss: 0.689782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid_0's binary_logloss: 0.689769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's binary_logloss: 0.689778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's binary_logloss: 0.689783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	valid_0's binary_logloss: 0.689789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's binary_logloss: 0.689776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's binary_logloss: 0.689758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's binary_logloss: 0.689741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	valid_0's binary_logloss: 0.689727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid_0's binary_logloss: 0.689706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's binary_logloss: 0.689805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	valid_0's binary_logloss: 0.689785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid_0's binary_logloss: 0.689771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	valid_0's binary_logloss: 0.689777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [218]	valid_0's binary_logloss: 0.689783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	valid_0's binary_logloss: 0.68977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	valid_0's binary_logloss: 0.689777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid_0's binary_logloss: 0.689784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [222]	valid_0's binary_logloss: 0.689767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	valid_0's binary_logloss: 0.689748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid_0's binary_logloss: 0.68973
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	valid_0's binary_logloss: 0.689717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid_0's binary_logloss: 0.689703
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid_0's binary_logloss: 0.68971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid_0's binary_logloss: 0.689697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid_0's binary_logloss: 0.689684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid_0's binary_logloss: 0.689673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's binary_logloss: 0.689681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	valid_0's binary_logloss: 0.68967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's binary_logloss: 0.68965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	valid_0's binary_logloss: 0.689656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's binary_logloss: 0.689663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's binary_logloss: 0.689671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's binary_logloss: 0.689677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's binary_logloss: 0.689684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's binary_logloss: 0.689691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's binary_logloss: 0.689679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's binary_logloss: 0.689687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's binary_logloss: 0.689695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's binary_logloss: 0.689702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's binary_logloss: 0.689695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's binary_logloss: 0.689681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's binary_logloss: 0.689662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's binary_logloss: 0.689649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's binary_logloss: 0.689654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's binary_logloss: 0.689635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's binary_logloss: 0.689643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's binary_logloss: 0.689626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's binary_logloss: 0.689613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's binary_logloss: 0.689622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's binary_logloss: 0.689611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's binary_logloss: 0.689619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's binary_logloss: 0.689626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's binary_logloss: 0.689613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's binary_logloss: 0.689619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's binary_logloss: 0.689626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's binary_logloss: 0.689613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's binary_logloss: 0.689619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's binary_logloss: 0.689624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's binary_logloss: 0.689632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's binary_logloss: 0.689708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's binary_logloss: 0.689697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's binary_logloss: 0.689704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's binary_logloss: 0.689692
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's binary_logloss: 0.689675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's binary_logloss: 0.689662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's binary_logloss: 0.689649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's binary_logloss: 0.689656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's binary_logloss: 0.689662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's binary_logloss: 0.689669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's binary_logloss: 0.689652
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's binary_logloss: 0.689629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's binary_logloss: 0.689637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's binary_logloss: 0.689619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's binary_logloss: 0.689594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's binary_logloss: 0.689602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's binary_logloss: 0.689588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's binary_logloss: 0.689594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's binary_logloss: 0.689602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's binary_logloss: 0.689588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's binary_logloss: 0.689594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's binary_logloss: 0.689576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's binary_logloss: 0.689583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's binary_logloss: 0.689559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's binary_logloss: 0.689567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's binary_logloss: 0.689574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's binary_logloss: 0.689561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's binary_logloss: 0.689548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's binary_logloss: 0.689556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's binary_logloss: 0.689532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's binary_logloss: 0.689539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's binary_logloss: 0.689547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's binary_logloss: 0.689553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's binary_logloss: 0.689534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's binary_logloss: 0.689541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's binary_logloss: 0.689527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's binary_logloss: 0.689504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's binary_logloss: 0.689494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's binary_logloss: 0.689483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's binary_logloss: 0.689492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's binary_logloss: 0.689469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's binary_logloss: 0.689456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's binary_logloss: 0.689465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's binary_logloss: 0.68944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	valid_0's binary_logloss: 0.689448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	valid_0's binary_logloss: 0.689435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310]	valid_0's binary_logloss: 0.689412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's binary_logloss: 0.689399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [312]	valid_0's binary_logloss: 0.689408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	valid_0's binary_logloss: 0.689416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's binary_logloss: 0.689402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	valid_0's binary_logloss: 0.689391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's binary_logloss: 0.689378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's binary_logloss: 0.689385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's binary_logloss: 0.689372
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's binary_logloss: 0.689381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's binary_logloss: 0.689387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's binary_logloss: 0.689396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's binary_logloss: 0.689405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's binary_logloss: 0.689412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's binary_logloss: 0.68942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's binary_logloss: 0.689396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's binary_logloss: 0.689379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's binary_logloss: 0.689385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's binary_logloss: 0.68936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's binary_logloss: 0.689368
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's binary_logloss: 0.689375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's binary_logloss: 0.689382
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's binary_logloss: 0.689369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's binary_logloss: 0.689377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's binary_logloss: 0.689441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's binary_logloss: 0.689433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's binary_logloss: 0.689442
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's binary_logloss: 0.689449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's binary_logloss: 0.689425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's binary_logloss: 0.689432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's binary_logloss: 0.689408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's binary_logloss: 0.689418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's binary_logloss: 0.689398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's binary_logloss: 0.689405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's binary_logloss: 0.689392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's binary_logloss: 0.689377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's binary_logloss: 0.689385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's binary_logloss: 0.689375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's binary_logloss: 0.689364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's binary_logloss: 0.689372
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's binary_logloss: 0.689381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's binary_logloss: 0.689439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's binary_logloss: 0.689445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's binary_logloss: 0.689454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's binary_logloss: 0.689431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's binary_logloss: 0.689438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's binary_logloss: 0.689487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's binary_logloss: 0.689494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's binary_logloss: 0.689502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's binary_logloss: 0.689508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's binary_logloss: 0.689495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's binary_logloss: 0.689501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's binary_logloss: 0.689479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's binary_logloss: 0.689488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's binary_logloss: 0.689475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's binary_logloss: 0.689481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's binary_logloss: 0.689467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's binary_logloss: 0.689515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's binary_logloss: 0.689522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's binary_logloss: 0.689504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's binary_logloss: 0.689511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's binary_logloss: 0.689496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's binary_logloss: 0.689502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's binary_logloss: 0.689489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's binary_logloss: 0.689475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's binary_logloss: 0.689482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's binary_logloss: 0.68949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's binary_logloss: 0.689466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's binary_logloss: 0.689452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's binary_logloss: 0.689433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's binary_logloss: 0.689415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's binary_logloss: 0.689423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's binary_logloss: 0.68943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's binary_logloss: 0.689438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's binary_logloss: 0.689427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's binary_logloss: 0.689414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's binary_logloss: 0.689421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's binary_logloss: 0.689429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's binary_logloss: 0.68941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's binary_logloss: 0.689403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's binary_logloss: 0.68941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's binary_logloss: 0.689417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's binary_logloss: 0.689425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's binary_logloss: 0.689433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's binary_logloss: 0.689481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's binary_logloss: 0.689489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's binary_logloss: 0.689474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's binary_logloss: 0.689482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's binary_logloss: 0.689468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's binary_logloss: 0.689474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's binary_logloss: 0.689461
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's binary_logloss: 0.689468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's binary_logloss: 0.689455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	valid_0's binary_logloss: 0.689437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	valid_0's binary_logloss: 0.689445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's binary_logloss: 0.689431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's binary_logloss: 0.689439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	valid_0's binary_logloss: 0.689425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	valid_0's binary_logloss: 0.689407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's binary_logloss: 0.689383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's binary_logloss: 0.689391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's binary_logloss: 0.689398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	valid_0's binary_logloss: 0.689407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	valid_0's binary_logloss: 0.689415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	valid_0's binary_logloss: 0.689423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2034]	valid_0's binary_logloss: 0.68286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2035]	valid_0's binary_logloss: 0.682876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2036]	valid_0's binary_logloss: 0.68288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2037]	valid_0's binary_logloss: 0.682865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2038]	valid_0's binary_logloss: 0.682868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2039]	valid_0's binary_logloss: 0.682857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2040]	valid_0's binary_logloss: 0.682862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2041]	valid_0's binary_logloss: 0.682866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2042]	valid_0's binary_logloss: 0.682856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2043]	valid_0's binary_logloss: 0.682862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2044]	valid_0's binary_logloss: 0.682851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2045]	valid_0's binary_logloss: 0.682829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2046]	valid_0's binary_logloss: 0.682847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2047]	valid_0's binary_logloss: 0.682827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2048]	valid_0's binary_logloss: 0.682831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2049]	valid_0's binary_logloss: 0.682836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2050]	valid_0's binary_logloss: 0.68284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2051]	valid_0's binary_logloss: 0.682857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2052]	valid_0's binary_logloss: 0.682861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2053]	valid_0's binary_logloss: 0.682849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2054]	valid_0's binary_logloss: 0.682838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2055]	valid_0's binary_logloss: 0.682842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2056]	valid_0's binary_logloss: 0.682847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2057]	valid_0's binary_logloss: 0.682836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2058]	valid_0's binary_logloss: 0.682825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2059]	valid_0's binary_logloss: 0.682829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2060]	valid_0's binary_logloss: 0.682814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2061]	valid_0's binary_logloss: 0.682805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2062]	valid_0's binary_logloss: 0.682809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2063]	valid_0's binary_logloss: 0.6828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2064]	valid_0's binary_logloss: 0.682803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2065]	valid_0's binary_logloss: 0.682782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2066]	valid_0's binary_logloss: 0.682786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2067]	valid_0's binary_logloss: 0.68279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2068]	valid_0's binary_logloss: 0.682794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2069]	valid_0's binary_logloss: 0.682776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2070]	valid_0's binary_logloss: 0.682781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2071]	valid_0's binary_logloss: 0.682796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2072]	valid_0's binary_logloss: 0.682799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2073]	valid_0's binary_logloss: 0.682803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2074]	valid_0's binary_logloss: 0.682807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2075]	valid_0's binary_logloss: 0.682796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2076]	valid_0's binary_logloss: 0.682799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2077]	valid_0's binary_logloss: 0.682787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2078]	valid_0's binary_logloss: 0.682792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2079]	valid_0's binary_logloss: 0.68278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2080]	valid_0's binary_logloss: 0.682783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2081]	valid_0's binary_logloss: 0.682789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2082]	valid_0's binary_logloss: 0.68278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2083]	valid_0's binary_logloss: 0.682771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2084]	valid_0's binary_logloss: 0.682749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2085]	valid_0's binary_logloss: 0.682756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2086]	valid_0's binary_logloss: 0.682761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2087]	valid_0's binary_logloss: 0.682765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2088]	valid_0's binary_logloss: 0.682747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2089]	valid_0's binary_logloss: 0.682751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2090]	valid_0's binary_logloss: 0.682756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2091]	valid_0's binary_logloss: 0.682737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2092]	valid_0's binary_logloss: 0.682725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2093]	valid_0's binary_logloss: 0.682728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2094]	valid_0's binary_logloss: 0.682719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2095]	valid_0's binary_logloss: 0.682708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2096]	valid_0's binary_logloss: 0.682712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2097]	valid_0's binary_logloss: 0.682716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2098]	valid_0's binary_logloss: 0.682706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2099]	valid_0's binary_logloss: 0.682694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2100]	valid_0's binary_logloss: 0.682672
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2101]	valid_0's binary_logloss: 0.682676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2102]	valid_0's binary_logloss: 0.682682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2103]	valid_0's binary_logloss: 0.682686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2104]	valid_0's binary_logloss: 0.68269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2105]	valid_0's binary_logloss: 0.682693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2106]	valid_0's binary_logloss: 0.682684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2107]	valid_0's binary_logloss: 0.682689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2108]	valid_0's binary_logloss: 0.682674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2109]	valid_0's binary_logloss: 0.682679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2110]	valid_0's binary_logloss: 0.682685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2111]	valid_0's binary_logloss: 0.682688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2112]	valid_0's binary_logloss: 0.682679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2113]	valid_0's binary_logloss: 0.682681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2114]	valid_0's binary_logloss: 0.682686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2115]	valid_0's binary_logloss: 0.682675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2116]	valid_0's binary_logloss: 0.682679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2117]	valid_0's binary_logloss: 0.682657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2118]	valid_0's binary_logloss: 0.682646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2119]	valid_0's binary_logloss: 0.682649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2120]	valid_0's binary_logloss: 0.682637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2121]	valid_0's binary_logloss: 0.682628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2122]	valid_0's binary_logloss: 0.682633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2123]	valid_0's binary_logloss: 0.682637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2124]	valid_0's binary_logloss: 0.68264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2125]	valid_0's binary_logloss: 0.682644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2126]	valid_0's binary_logloss: 0.682659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2127]	valid_0's binary_logloss: 0.682664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2128]	valid_0's binary_logloss: 0.682669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2129]	valid_0's binary_logloss: 0.682658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2130]	valid_0's binary_logloss: 0.68264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2131]	valid_0's binary_logloss: 0.682644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2132]	valid_0's binary_logloss: 0.682632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2133]	valid_0's binary_logloss: 0.682637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2134]	valid_0's binary_logloss: 0.682641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2135]	valid_0's binary_logloss: 0.682645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2136]	valid_0's binary_logloss: 0.682648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2137]	valid_0's binary_logloss: 0.682653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2138]	valid_0's binary_logloss: 0.682637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2139]	valid_0's binary_logloss: 0.682628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2140]	valid_0's binary_logloss: 0.682632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2141]	valid_0's binary_logloss: 0.68262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2142]	valid_0's binary_logloss: 0.682625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2143]	valid_0's binary_logloss: 0.682629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2144]	valid_0's binary_logloss: 0.682634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2145]	valid_0's binary_logloss: 0.682637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2146]	valid_0's binary_logloss: 0.68264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2147]	valid_0's binary_logloss: 0.682629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2148]	valid_0's binary_logloss: 0.682633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2149]	valid_0's binary_logloss: 0.682636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2150]	valid_0's binary_logloss: 0.682625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2151]	valid_0's binary_logloss: 0.682629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2152]	valid_0's binary_logloss: 0.68261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2153]	valid_0's binary_logloss: 0.682614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2154]	valid_0's binary_logloss: 0.682603
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2155]	valid_0's binary_logloss: 0.682609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2156]	valid_0's binary_logloss: 0.682598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2157]	valid_0's binary_logloss: 0.682603
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2158]	valid_0's binary_logloss: 0.682592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2159]	valid_0's binary_logloss: 0.682583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2160]	valid_0's binary_logloss: 0.682571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2161]	valid_0's binary_logloss: 0.682576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2162]	valid_0's binary_logloss: 0.682583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2163]	valid_0's binary_logloss: 0.682571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2164]	valid_0's binary_logloss: 0.68255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2165]	valid_0's binary_logloss: 0.682539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2166]	valid_0's binary_logloss: 0.682528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2167]	valid_0's binary_logloss: 0.682516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2168]	valid_0's binary_logloss: 0.682519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2169]	valid_0's binary_logloss: 0.682523
# ******* No.2 BS Process is Done! ********
# **** End of BayesSearchCV Process ****

# %%
df_one = df_combine_sorted(df_base, df_params)

# %%
row_index =  ['train_precision', 'val_precision', 'test_precision']
df_style(df_one.iloc[52:80, :], row_index)
# Out:
# <style type="text/css">
# #T_4da78_row5_col0, #T_4da78_row5_col1, #T_4da78_row10_col0, #T_4da78_row10_col1, #T_4da78_row15_col0, #T_4da78_row15_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_4da78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4da78_level0_col0" class="col_heading level0 col0" >parameter</th>
#       <th id="T_4da78_level0_col1" class="col_heading level0 col1" >iter_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4da78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4da78_row0_col0" class="data row0 col0" >best_score</td>
#       <td id="T_4da78_row0_col1" class="data row0 col1" >0.660706</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4da78_row1_col0" class="data row1 col0" >best_index</td>
#       <td id="T_4da78_row1_col1" class="data row1 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4da78_row2_col0" class="data row2 col0" >acc_train</td>
#       <td id="T_4da78_row2_col1" class="data row2 col1" >0.808824</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4da78_row3_col0" class="data row3 col0" >acc_val</td>
#       <td id="T_4da78_row3_col1" class="data row3 col1" >0.686275</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4da78_row4_col0" class="data row4 col0" >acc_test</td>
#       <td id="T_4da78_row4_col1" class="data row4 col1" >0.593750</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4da78_row5_col0" class="data row5 col0" >train_precision</td>
#       <td id="T_4da78_row5_col1" class="data row5 col1" >0.849315</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4da78_row6_col0" class="data row6 col0" >train_tn</td>
#       <td id="T_4da78_row6_col1" class="data row6 col1" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4da78_row7_col0" class="data row7 col0" >train_fp</td>
#       <td id="T_4da78_row7_col1" class="data row7 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4da78_row8_col0" class="data row8 col0" >train_fn</td>
#       <td id="T_4da78_row8_col1" class="data row8 col1" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4da78_row9_col0" class="data row9 col0" >train_tp</td>
#       <td id="T_4da78_row9_col1" class="data row9 col1" >62.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4da78_row10_col0" class="data row10 col0" >val_precision</td>
#       <td id="T_4da78_row10_col1" class="data row10 col1" >0.733333</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4da78_row11_col0" class="data row11 col0" >val_tn</td>
#       <td id="T_4da78_row11_col1" class="data row11 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4da78_row12_col0" class="data row12 col0" >val_fp</td>
#       <td id="T_4da78_row12_col1" class="data row12 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4da78_row13_col0" class="data row13 col0" >val_fn</td>
#       <td id="T_4da78_row13_col1" class="data row13 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4da78_row14_col0" class="data row14 col0" >val_tp</td>
#       <td id="T_4da78_row14_col1" class="data row14 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4da78_row15_col0" class="data row15 col0" >test_precision</td>
#       <td id="T_4da78_row15_col1" class="data row15 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4da78_row16_col0" class="data row16 col0" >recall</td>
#       <td id="T_4da78_row16_col1" class="data row16 col1" >0.342857</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4da78_row17_col0" class="data row17 col0" >f1score</td>
#       <td id="T_4da78_row17_col1" class="data row17 col1" >0.480000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4da78_row18_col0" class="data row18 col0" >roc</td>
#       <td id="T_4da78_row18_col1" class="data row18 col1" >0.619704</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4da78_row19_col0" class="data row19 col0" >test_tn</td>
#       <td id="T_4da78_row19_col1" class="data row19 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4da78_row20_col0" class="data row20 col0" >test_fp</td>
#       <td id="T_4da78_row20_col1" class="data row20 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4da78_row21_col0" class="data row21 col0" >test_fn</td>
#       <td id="T_4da78_row21_col1" class="data row21 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4da78_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4da78_row22_col0" class="data row22 col0" >test_tp</td>
#       <td id="T_4da78_row22_col1" class="data row22 col1" >12.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
row_index = ['n_estimators', 'reg_alpha', 'max_bin', 'subsample_for_bin']
df_style(df_one.head(60), row_index)
# Out:
# <style type="text/css">
# #T_c7124_row17_col0, #T_c7124_row17_col1, #T_c7124_row27_col0, #T_c7124_row27_col1, #T_c7124_row37_col0, #T_c7124_row37_col1, #T_c7124_row48_col0, #T_c7124_row48_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c7124">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7124_level0_col0" class="col_heading level0 col0" >parameter</th>
#       <th id="T_c7124_level0_col1" class="col_heading level0 col1" >iter_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7124_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7124_row0_col0" class="data row0 col0" >boost_from_average</td>
#       <td id="T_c7124_row0_col1" class="data row0 col1" >[True, False]</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7124_row1_col0" class="data row1 col0" >boost_from_average</td>
#       <td id="T_c7124_row1_col1" class="data row1 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7124_row2_col0" class="data row2 col0" >boosting_type</td>
#       <td id="T_c7124_row2_col1" class="data row2 col1" >['gbdt', 'dart']</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7124_row3_col0" class="data row3 col0" >boosting_type</td>
#       <td id="T_c7124_row3_col1" class="data row3 col1" >dart</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7124_row4_col0" class="data row4 col0" >class_weight</td>
#       <td id="T_c7124_row4_col1" class="data row4 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7124_row5_col0" class="data row5 col0" >colsample_bytree</td>
#       <td id="T_c7124_row5_col1" class="data row5 col1" >(0.5, 1.0, 'uniform')</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7124_row6_col0" class="data row6 col0" >colsample_bytree</td>
#       <td id="T_c7124_row6_col1" class="data row6 col1" >0.799024</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7124_row7_col0" class="data row7 col0" >cv</td>
#       <td id="T_c7124_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7124_row8_col0" class="data row8 col0" >cv</td>
#       <td id="T_c7124_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7124_row9_col0" class="data row9 col0" >force_col_wise</td>
#       <td id="T_c7124_row9_col1" class="data row9 col1" >['true']</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7124_row10_col0" class="data row10 col0" >force_col_wise</td>
#       <td id="T_c7124_row10_col1" class="data row10 col1" >true</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7124_row11_col0" class="data row11 col0" >importance_type</td>
#       <td id="T_c7124_row11_col1" class="data row11 col1" >split</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c7124_row12_col0" class="data row12 col0" >importance_type</td>
#       <td id="T_c7124_row12_col1" class="data row12 col1" >['split']</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c7124_row13_col0" class="data row13 col0" >iterations</td>
#       <td id="T_c7124_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c7124_row14_col0" class="data row14 col0" >iterations</td>
#       <td id="T_c7124_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c7124_row15_col0" class="data row15 col0" >learning_rate</td>
#       <td id="T_c7124_row15_col1" class="data row15 col1" >(0.0001, 0.004, 'log-uniform')</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c7124_row16_col0" class="data row16 col0" >learning_rate</td>
#       <td id="T_c7124_row16_col1" class="data row16 col1" >0.000142</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c7124_row17_col0" class="data row17 col0" >max_bin</td>
#       <td id="T_c7124_row17_col1" class="data row17 col1" >780</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c7124_row18_col0" class="data row18 col0" >max_bin</td>
#       <td id="T_c7124_row18_col1" class="data row18 col1" >(100, 1000)</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c7124_row19_col0" class="data row19 col0" >max_depth</td>
#       <td id="T_c7124_row19_col1" class="data row19 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c7124_row20_col0" class="data row20 col0" >max_depth</td>
#       <td id="T_c7124_row20_col1" class="data row20 col1" >(0, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c7124_row21_col0" class="data row21 col0" >metric</td>
#       <td id="T_c7124_row21_col1" class="data row21 col1" >['binary_logloss']</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c7124_row22_col0" class="data row22 col0" >metric</td>
#       <td id="T_c7124_row22_col1" class="data row22 col1" >binary_logloss</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c7124_row23_col0" class="data row23 col0" >min_child_samples</td>
#       <td id="T_c7124_row23_col1" class="data row23 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_c7124_row24_col0" class="data row24 col0" >min_child_samples</td>
#       <td id="T_c7124_row24_col1" class="data row24 col1" >(5, 40)</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_c7124_row25_col0" class="data row25 col0" >min_child_weight</td>
#       <td id="T_c7124_row25_col1" class="data row25 col1" >0.001000</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_c7124_row26_col0" class="data row26 col0" >min_split_gain</td>
#       <td id="T_c7124_row26_col1" class="data row26 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_c7124_row27_col0" class="data row27 col0" >n_estimators</td>
#       <td id="T_c7124_row27_col1" class="data row27 col1" >(700, 5000)</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_c7124_row28_col0" class="data row28 col0" >n_estimators</td>
#       <td id="T_c7124_row28_col1" class="data row28 col1" >2169</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_c7124_row29_col0" class="data row29 col0" >n_jobs</td>
#       <td id="T_c7124_row29_col1" class="data row29 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c7124_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_c7124_row30_col0" class="data row30 col0" >num_col</td>

# %%
# parameter 조합별 측정치 비교
df_result =  pd.DataFrame(lgbmBS.cv_results_)
df_result.loc[:, ['mean_test_score', 'std_test_score', 'rank_test_score']].sort_values(by='mean_test_score', ascending=False)
# Out:
#    mean_test_score  std_test_score  rank_test_score
# 3         0.660706        0.161097                1
# 5         0.637637        0.216481                2
# 6         0.608476        0.086705                3
# 2         0.600253        0.134237                4
# 8         0.594343        0.221453                5
# 0         0.569670        0.065954                6
# 9         0.540773        0.062334                7
# 4         0.510779        0.076213                8
# 7         0.181538        0.240788                9
# 1         0.000000        0.000000               10

# %%
# parameter 조합별 측정치 비교
df_result =  pd.DataFrame(lgbmBS.evals_result_)
df_result.loc[:, ['mean_test_score', 'std_test_score', 'rank_test_score']].sort_values(by='mean_test_score', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [36], line 2
#       1 # parameter 조합별 측정치 비교
# ----> 2 df_result =  pd.DataFrame(lgbmBS.evals_result_)
#       3 df_result.loc[:, ['mean_test_score', 'std_test_score', 'rank_test_score']].sort_values(by='mean_test_score', ascending=False)
#
# AttributeError: 'BayesSearchCV' object has no attribute 'evals_result_'

# %%
# search_space, parameters and results save
df_one.to_csv(f'{directory_for_model}{com_name}/params_results_{gsbs}_df_{dt}.csv')
df_one.to_pickle(f'{directory_for_model}{com_name}/params_results_{gsbs}_df_{dt}.pkl')

# %%
# 아래 내용은 위의 df_one을 대체함.
# parameter and results save
df_base.to_csv(f'{directory_for_model}{com_name}/lgbm_{gsbs}_df_{dt}.csv')
df_base.to_pickle(f'{directory_for_model}{com_name}/lgbm_{gsbs}_df_{dt}.pkl')

# search_space, parameters save
df_params.to_csv(f'{directory_for_model}{com_name}/params_{gsbs}_df_{dt}.csv')
df_params.to_pickle(f'{directory_for_model}{com_name}/params_{gsbs}_df_{dt}.pkl')

# %%
'''
# save model
# 필요시 저장. 가장 좋은 결과만 저장하고자할 때는 밑의 save_best_results만 진행하면 됨.
joblib.dump(lgbmBS.best_estimator_, f'{directory_for_model}{com_name}/estimator_{gsbs}_{dt}_v{iter}.pkl') # bayessearchcv 저장
save_to_pickle(f'{directory_for_model}{com_name}/model_{gsbs}_{dt}_v{iter}_p.pkl', lgbmBS.best_estimator_)
joblib.dump(scaler, f'{directory_for_model}{com_name}/scaler_{gsbs}_{dt}_v{iter}.pkl') # scaler 저장
save_to_pickle(f'{directory_for_model}{com_name}/columns_{gsbs}_{dt}_{len(new_col)}_{round(precision*100):2d}%_{round(f1score*100):2d}%_ver{iter}.pkl', new_col)
save_list_to_csv(f'{directory_for_model}{com_name}/columns_{gsbs}_{dt}_{len(new_col)}_{round(precision*100):2d}%_{round(f1score*100):2d}%_ver{iter}.csv', new_col)
'''

# %%
# 최종 가장 좋은 결과 저장
save_best_results(com_name, lgbmBS.best_estimator_, scaler, new_col, df_base)

# %%
print(lgbmBS.best_estimator_)

# %%
model = lgbmBS.best_estimator_
feature_df = pd.DataFrame(model.booster_.feature_importance(importance_type='gain'), 
                      index=data.columns, columns=['importance']).sort_values(by='importance', 
                                                                              ascending=False)

# %%
len(feature_df)

# %%
feature_df.tail(70)

# %%
new_col = list(feature_df.index[:35]) +  ['cr_00', 'cr_05', 'cr_10', 'cr_15', 'cr_20']

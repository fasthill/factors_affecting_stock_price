# %% [markdown]
# <a href="https://colab.research.google.com/github/fasthill/ML-DL-study-alone/blob/main/5-1%20%EA%B2%B0%EC%A0%95%20%ED%8A%B8%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analyse from LightGBM

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/5-1.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
import datetime
import os, re

# %%
df_estimator = make_df_from_estimator(lgbmgs.best_estimator_.get_params(), 1)
result_dict = calc_results(lgbmgs.best_estimator_, train_scaled, val_scaled, test_scaled, test_target)
df_result = make_df_from_estimator(result_dict, 1)
df_concat = pd.concat([df_estimator, df_result])

# %%
df_base = pd.merge(df_base,df_concat, how='outer', left_index=True, right_index=True)

# %%
max_depth = [1,2,3,4,5],
njm_leaves = [3,4,5,6,7],
learning_rate = [0.03, 0.05, 0.1, 0.2, 0.3]
colsample_bytree = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
subsample = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
n_estimator =[5, 10, 15, 20]
num_class = [1]

num_leaves = 20~3000
max_depth = 3 ~12
learning_rate = 0.01 ~ 0.3

parameters = {'learning_rate': [0.01,0.02,0.03],
                  'subsample'    : [0.9, 0.5, 0.2],
                  'n_estimators' : [100,500,1000],
                  'max_depth'    : [4,6,8]

# %%
sec1 = " \feature_fraction=0.8, bagging_fraction=0.9, \
train accuracy: 1.0000, val accuracy= 0.7907, test accuracy= 0.8519, \
precision : 0.7368, recall : 0.8235, f1score : 0.7778, roc : 0.8442, \
tn= 32, fp=5, fn=3, tp=14"


sec2 = "colsample_bytree=0.41, eval_metric='logloss', \
               learning_rate=0.004, max_delta_step=0.5, max_depth=2, \
               metric='loss', n_estimators=5, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.005, \
boosting_type: 'gbdt', colsample_bytree: 0.41, \
learning_rate: 0.004, max_depth: 2, metric: 'loss', n_estimators: 5, \
num_leaves: 3, objective: 'binary', subsample: 0.005, \
Best Score: 0.9333333333333332, Best Index: 0, \
train accuracy: 0.8081, val accuracy= 0.7442, test accuracy= 0.7593, \
precision : 1.0000, recall : 0.2353, f1score : 0.3810, roc : 0.6176, \
tn= 37, fp=0, fn=13, tp=4"

sec3 = "bagging_fraction=0.9, colsample_bytree=0.5, feature_fraction=0.8, \
               learning_rate=0.05, max_delta_step=0.5, max_depth=2, \
               metric='auc', num_iterations=500, num_leaves=4, \
               objective='binary', random_state=42, subsample=0.5, \
boosting_type: 'gbdt', colsample_bytree: 0.5, \
                  learning_rate: 0.05, max_depth: 2, \
                  metric: 'auc', n_estimators: 100, num_leaves: 4, \
                  objective: 'binary', subsample: 0.5, \
Best Score: 0.8375180375180376, Best Index: 726, \
train accuracy: 1.0000, val accuracy= 0.7907, test accuracy= 0.8148, \
precision : 0.7059, recall : 0.7059, f1score : 0.7059, roc : 0.7854, \
tn=32, fp=5, fn=5, tp=12"


sec4 = "bagging_fraction=0.9, colsample_bytree=0.3, feature_fraction=0.8, \
               max_delta_step=0.5, max_depth=4, metric='rmse', n_estimators=80, \
               num_iterations=500, num_leaves=6, objective='binary',\
               random_state=42, subsample=0.3, \
boosting_type: 'gbdt', colsample_bytree: 0.3, learning_rate: 0.1, \
                  max_depth: 4, metric: 'rmse', n_estimators: 80, num_leaves: 6, \
                  objective: 'binary', subsample: 0.3, \
Best Score: 0.8377777777777778, Best Index: 915, \
train accuracy: 1.0000, val accuracy= 0.7907, test accuracy= 0.8519, \
precision : 0.7368, recall : 0.8235, f1score : 0.7778, roc : 0.8442, \
tn=32, fp=5, fn=3, tp=14"

sec5 = "bagging_fraction=0.9, colsample_bytree=0.1, feature_fraction=0.8,\
               learning_rate=0.07, max_delta_step=0.5, max_depth=5,\
               metric='rmse', n_estimators=50, num_iterations=500, num_leaves=6,\
               objective='binary', random_state=42, subsample=0.1, \
boosting_type: 'gbdt', colsample_bytree: 0.1, learning_rate: 0.07, \
                max_depth: 5, metric: 'rmse', n_estimators: 50, num_leaves: 6, \
                  objective: 'binary', subsample: 0.1, \
Best Score: 0.8377777777777778, Best Index: 315, \
train accuracy: 1.0000, val accuracy= 0.8140, test accuracy= 0.8519, \
precision : 0.7368, recall : 0.8235, f1score : 0.7778, roc : 0.8442, \
tn=32, fp=5, fn=3, tp=14"


sec6 = "colsample_bytree=0.4, learning_rate=0.03, max_delta_step=0.5, \
               max_depth=3, metric='loss', n_estimators=30, num_iterations=500, \
               num_leaves=4, objective='binary', random_state=42, \
               subsample=0.1, \
boosting_type: 'gbdt', colsample_bytree: 0.4,  \
                                    learning_rate: 0.03, max_depth: 3, metric: 'loss',  \
                                    n_estimators: 30, num_leaves: 4, objective: 'binary', subsample: 0.1, \
Best Score: 0.8342857142857143, Best Index: 7605, \
train accuracy: 1.0000, val accuracy= 0.7907, test accuracy= 0.8704, \
precision : 0.7500, recall : 0.8824, f1score : 0.8108, roc : 0.8736, \
tn=32, fp=5, fn=2, tp=15"

sec7 = "colsample_bytree=0.35, eval_metric='logloss', learning_rate=0.02, \
               max_delta_step=0.5, max_depth=3, metric='loss', n_estimators=10, \
               num_iterations=100, num_leaves=4, objective='binary', \
               random_state=42, subsample=0.05, \
boosting_type: 'gbdt', colsample_bytree: 0.35, learning_rate: 0.02, \
                max_depth: 3, metric: 'loss', n_estimators: 10, 'num_iterations': 100, \
                num_leaves: 4, objective: 'binary', subsample: 0.05, \
Best Score: 1.0, Best Index: 1204, \
train accuracy: 0.7849, val accuracy= 0.7442, test accuracy= 0.7037, \
precision : 1.0000, recall : 0.0588, f1score : 0.1111, roc : 0.5294, \
tn=37, fp=0, fn=16, tp=1"

sec8 = "colsample_bytree=0.45, eval_metric='logloss', learning_rate=0.01, \
               max_delta_step=0.5, max_depth=2, metric='loss', n_estimators=10, \
               num_iterations=300, num_leaves=3, objective='binary', \
               random_state=42, subsample=0.05, \
boosting_type: 'gbdt', colsample_bytree: 0.45, learning_rate: 0.01, \
                max_depth: 2, metric: 'loss', n_estimators: 10, num_leaves: 3, \
                objective: 'binary', subsample: 0.05, \
Best Score: 0.8638888888888889, Best Index: 1800, \
train accuracy: 0.9128, val accuracy= 0.8140, test accuracy= 0.8519, \
precision : 0.8000, recall : 0.7059, f1score : 0.7500, roc : 0.8124, \
tn=34, fp=3, fn=5, tp=12"

sec9 = "colsample_bytree=0.4, eval_metric='logloss', learning_rate=0.01, \
               max_delta_step=0.5, max_depth=2, metric='loss', n_estimators=5, \
               num_iterations=200, num_leaves=3, objective='binary', \
               random_state=42, subsample=0.03, \
boosting_type: 'gbdt', colsample_bytree: 0.4, learning_rate: 0.01,\
                 max_depth: 2, metric: 'loss', n_estimators: 5, num_leaves: 3, \
                objective: 'binary', subsample: 0.03, \
Best Score: 0.9333333333333332, Best Index: 144, \
train accuracy: 0.8023, val accuracy= 0.7442, test accuracy= 0.7593, \
precision : 1.0000, recall : 0.2353, f1score : 0.3810, roc : 0.6176, \
tn=37, fp=0, fn=13, tp=4"


sec10 = "colsample_bytree=0.42, eval_metric='logloss', learning_rate=0.01, \
               max_delta_step=0.5, max_depth=2, metric='loss', n_estimators=5, \ \
               num_iterations=300, num_leaves=3, objective='binary', \
               random_state=42, subsample=0.03, \
boosting_type: 'gbdt', colsample_bytree: 0.42, learning_rate: 0.01, \
                max_depth: 2, metric: 'loss', n_estimators: 5, num_leaves: 3, \
                objective: 'binary', subsample: 0.03, \
Best Score: 0.8638888888888889, Best Index: 720, \
train accuracy: 0.9070, val accuracy= 0.8140, test accuracy= 0.8519, \
precision : 0.8000, recall : 0.7059, f1score : 0.7500, roc : 0.8124, \
tn=34, fp=3, fn=5, tp=12"

sec11 = "colsample_bytree=0.42, eval_metric='logloss', \
               learning_rate=0.005, max_delta_step=0.5, max_depth=2, \
               metric='loss', n_estimators=5, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.01, \
boosting_type: 'gbdt', colsample_bytree: 0.42, learning_rate: 0.005, \
                max_depth: 2, metric: 'loss', n_estimators: 5, num_leaves: 3, \
                objective: 'binary', subsample: 0.01, \
Best Score: 0.8355555555555556, Best Index: 432, \
train accuracy: 0.8895, val accuracy= 0.8372, test accuracy= 0.8519, \
precision : 0.8462, recall : 0.6471, f1score : 0.7333, roc : 0.7965, \
tn=35, fp=2, fn=6, tp=11"

sec12 = "colsample_bytree=0.41, eval_metric='logloss', \
               learning_rate=0.004, max_delta_step=0.5, max_depth=2, \
               metric='loss', n_estimators=5, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.005, \
boosting_type: 'gbdt', colsample_bytree: 0.41, learning_rate: 0.004, \
                max_depth: 2, metric: 'loss', n_estimators: 5, num_leaves: 3, \
                objective: 'binary', subsample: 0.005, \
Best Score: 0.9333333333333332, Best Index: 0, \
train accuracy: 0.8081, val accuracy= 0.7442, test accuracy= 0.7593, \
precision : 1.0000, recall : 0.2353, f1score : 0.3810, roc : 0.6176, \
tn=37, fp=0, fn=13, tp=4"

# %%
sec2.replace(" ","")
# Out:
# "colsample_bytree=0.41,eval_metric='logloss',learning_rate=0.004,max_delta_step=0.5,max_depth=2,metric='loss',n_estimators=5,num_iterations=500,num_leaves=3,objective='binary',random_state=42,subsample=0.005,boosting_type:'gbdt',colsample_bytree:0.41,learning_rate:0.004,max_depth:2,metric:'loss',n_estimators:5,num_leaves:3,objective:'binary',subsample:0.005,BestScore:0.9333333333333332,BestIndex:0,trainaccuracy:0.8081,valaccuracy=0.7442,testaccuracy=0.7593,precision:1.0000,recall:0.2353,f1score:0.3810,roc:0.6176,tn=37,fp=0,fn=13,tp=4"

# %%
sec1 = sec1.replace(" ","")

# %%
for i in range(1, 13, 1):
    globals()[f'sec{i}_nospace'] = globals()[f'sec{i}'].replace(" ","")

# %%
nav1 = "feature_fraction=0.8, \
bagging_fraction=0.9, \
train accuracy: 1.0000, val accuracy= 0.8205, test accuracy= 0.7083, \
precision : 0.6111, recall : 0.6111, f1score : 0.6111, roc : 0.6889, \
tn=23, fp=7, fn=7, tp=11"

nav2 = "colsample_bytree=0.38, eval_metric='logloss', \
               learning_rate=0.005, max_delta_step=0.5, max_depth=None, \
               metric='loss', n_estimators=3, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.003, \
boosting_type: 'gbdt', colsample_bytree: 0.38, learning_rate: 0.005, \
                max_depth: None, metric: 'loss', n_estimators: 3, num_leaves: 3, \
                objective: 'binary', subsample: 0.003, \
Best Score: 0.8311827956989248, Best Index: 864, \
train accuracy: 0.8758, val accuracy= 0.8974, test accuracy= 0.7708, \
precision : 0.8182, recall : 0.5000, f1score : 0.6207, roc : 0.7167, \
tn=28, fp=2, fn=9, tp=9"


nav2 = "colsample_bytree=0.41, eval_metric='logloss', \
               learning_rate=0.004, max_delta_step=0.5, max_depth=2, \
               metric='loss', n_estimators=5, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.005, \
boosting_type: 'gbdt', colsample_bytree: 0.41, learning_rate: 0.004, \
                max_depth: 2, metric: 'loss', n_estimators: 5, num_leaves: 3, \
                objective: 'binary', subsample: 0.005, \
Best Score: 0.9444444444444444, Best Index: 0, \
train accuracy: 0.8758, val accuracy= 0.8974, test accuracy= 0.7917, \
precision : 0.9000, recall : 0.5000, f1score : 0.6429, roc : 0.7333, \
tn=29, fp=1, fn=9, tp=9"


nav3 = "colsample_bytree=0.38, eval_metric='logloss', \
               learning_rate=0.003, max_delta_step=0.5, max_depth=2, \
               metric='loss', n_estimators=3, num_iterations=500, num_leaves=3, \ \
               objective='binary', random_state=42, subsample=0.003, \
boosting_type: 'gbdt', colsample_bytree: 0.38, learning_rate: 0.003, \
                max_depth: 2, metric: 'loss', n_estimators: 3, num_leaves: 3, \
                objective: 'binary', subsample: 0.003, \
Best Score: 0.9777777777777779, Best Index: 216, \
train accuracy: 0.8170, val accuracy= 0.8462, test accuracy= 0.7292, \
precision : 0.8571, recall : 0.3333, f1score : 0.4800, roc : 0.6500, \
tn=29, fp=1, fn=12, tp=6"


#### scoring을 precision에서 default(accuracy)로 변경한 결과
nav4 = "colsample_bytree=0.38, eval_metric='logloss', \
               learning_rate=0.005, max_delta_step=0.5, max_depth=2, \
               metric='loss', n_estimators=3, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.003, \
boosting_type: 'gbdt', colsample_bytree: 0.38, learning_rate: 0.005, \
                max_depth: 2, metric: 'loss', n_estimators: 3, num_leaves: 3, \
                objective: 'binary', subsample: 0.003, \
Best Score: 0.8311827956989248, Best Index: 648, \
train accuracy: 0.8758, val accuracy 0.8974, test accuracy 0.7708, \
precision : 0.8182, recall : 0.5000, f1score : 0.6207, roc : 0.7167, \
tn=28, fp=2, fn=9, tp=9"

#### max_depth = None 삽입결과

nav5 = "colsample_bytree=0.38, eval_metric='logloss', \
               learning_rate=0.005, max_delta_step=0.5, max_depth=None, \
               metric='loss', n_estimators=3, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.003, \
boosting_type: 'gbdt', colsample_bytree: 0.38, learning_rate: 0.005, \
                max_depth: None, metric: 'loss', n_estimators: 3, num_leaves: 3, \
                objective: 'binary', subsample: 0.003, \
Best Score: 0.8311827956989248, Best Index: 864, \
train accuracy: 0.8758, val accuracy= 0.8974, test accuracy= 0.7708, \
precision : 0.8182, recall : 0.5000, f1score : 0.6207, roc : 0.7167, \
tn=28   , fp=2, fn=9  , tp=9   "

# %%
for i in range(1, 6, 1):
    globals()[f'nav{i}_nospace'] = globals()[f'nav{i}'].replace(" ","")

# %%
nav5_nospace.split(",")[13]
# Out:
# 'colsample_bytree:0.38'

# %%
skh1 = "colsample_bytree=0.36, learning_rate=0.008, max_delta_step=0.5, \
               max_depth=None, metric='loss', n_estimators=None, \
               num_iterations=500, num_leaves=3, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.36, learning_rate: 0.008, \
                max_depth: None, metric: 'loss', n_estimators: None, num_leaves: 3, \
                objective: 'binary', subsample: None, \
Best Score: 0.8201426024955436, Best Index: 1443, \
train accuracy: 0.8795, val accuracy= 0.8571, test accuracy= 0.8269, \
precision : 0.8571, recall : 0.6316, f1score : 0.7273, roc : 0.7855, \
tn=31, fp=2, fn=7, tp=12"

     
skh2 = "colsample_bytree=0.39, eval_metric='logloss', \
               learning_rate=0.005, max_delta_step=0.5, max_depth=None, \
               metric='loss', n_estimators=3, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.003, \
boosting_type: 'gbdt', colsample_bytree: 0.39, learning_rate: 0.005, \
                max_depth: None, metric: 'loss', n_estimators: 3, num_leaves: 3, \
                objective: 'binary', subsample: 0.003, \
Best Score: 0.7782531194295901, Best Index: 2016, \
train accuracy: 0.8434, val accuracy= 0.7857, test accuracy= 0.8077, \
precision : 0.8462, recall : 0.5789, f1score : 0.6875, roc : 0.7592, \
tn=31   , fp=2, fn=8  , tp= 11  "
     

skh3 = "colsample_bytree=0.36, eval_metric='logloss', \
               learning_rate=0.007, max_delta_step=0.5, max_depth=None, \
               metric='loss', n_estimators=3, num_iterations=500, num_leaves=3, \
               objective='binary', random_state=42, subsample=0.001, \
boosting_type: 'gbdt', colsample_bytree: 0.36, learning_rate: 0.007, \
                max_depth: None, metric: 'loss', n_estimators: 3, num_leaves: 3, \
                objective: 'binary', subsample: 0.001, \
Best Score: 0.8083778966131907, Best Index: 1152, \
train accuracy: 0.8795, val accuracy= 0.8571, test accuracy= 0.8269, \
precision : 0.8571, recall : 0.6316, f1score : 0.7273, roc : 0.7855, \
tn=31   , fp=2, fn=7  , tp=12   "

skh4 = "colsample_bytree=0.36, learning_rate=0.011, max_delta_step=0.5, \
               max_depth=None, metric='loss', n_estimators=3, \
               num_iterations=500, num_leaves=2, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.36, learning_rate: 0.011, \
                max_depth: None, metric: 'loss', n_estimators: 3, num_leaves: 2, \
                objective: 'binary', subsample: None, \
Best Score: 0.8199643493761141, Best Index: 3024, \
train accuracy: 0.8675, val accuracy= 0.8095, test accuracy= 0.8462, \
precision : 0.8667, recall : 0.6842, f1score : 0.7647, roc : 0.8118, \
tn=31   , fp=2, fn=6  , tp=13   "


skh5 = "colsample_bytree=0.34, learning_rate=0.01, max_delta_step=0.5, \
               max_depth=None, metric='loss', n_estimators=None, \
               num_iterations=500, num_leaves=3, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.34, learning_rate: 0.01, \
                max_depth: None, metric: 'loss', n_estimators: None, num_leaves: 3, \
                objective: 'binary', subsample: None, \
Best Score: 0.8199643493761141, Best Index: 3, \
train accuracy: 0.8916, val accuracy= 0.9048, test accuracy= 0.8462, \
precision : 0.8667, recall : 0.6842, f1score : 0.7647, roc : 0.8118, \
tn=31   , fp=2, fn=6  , tp= 13  "


skh6 = "colsample_bytree=0.36, learning_rate=0.008, max_delta_step=0.5, \
               max_depth=None, metric='loss', n_estimators=None, \
               num_iterations=500, num_leaves=3, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.36, learning_rate: 0.008, \
                max_depth: None, metric: 'loss', n_estimators: None, num_leaves: 3, \
                objective: 'binary', subsample: None, \
Best Score: 0.8201426024955436, Best Index: 2307, \
train accuracy: 0.8795, val accuracy= 0.8571, test accuracy= 0.8269, \
precision : 0.8571, recall : 0.6316, f1score : 0.7273, roc : 0.7855, \
tn=31   , fp=2, fn=7  , tp=12   "


skh7 = "colsample_bytree=0.36, learning_rate=0.008, max_delta_step=0.5, \
               max_depth=None, metric='loss', n_estimators=None, \
               num_iterations=500, num_leaves=3, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.36, learning_rate: 0.008,\
                max_depth: None, metric: 'loss', max_depth: None, num_leaves: 3, \
                objective: 'binary', subsample: None, \
Best Score: 0.8201426024955436, Best Index: 1443, \
train accuracy: 0.8795, val accuracy= 0.8571, test accuracy= 0.8269, \
precision : 0.8571, recall : 0.6316, f1score : 0.7273, roc : 0.7855, \
tn=31  , fp=2, fn=7  , tp=12   "

# %%
for i in range(1, 8, 1):
    globals()[f'skh{i}_nospace'] = globals()[f'skh{i}'].replace(" ","")

# %%
skh7_nospace
# Out:
# "colsample_bytree=0.36,learning_rate=0.008,max_delta_step=0.5,max_depth=None,metric='loss',n_estimators=None,num_iterations=500,num_leaves=3,objective='binary',random_state=42,subsample=None,boosting_type:'gbdt',colsample_bytree:0.36,learning_rate:0.008,max_depth:None,metric:'loss',max_depth:None,num_leaves:3,objective:'binary',subsample:None,BestScore:0.8201426024955436,BestIndex:1443,trainaccuracy:0.8795,valaccuracy=0.8571,testaccuracy=0.8269,precision:0.8571,recall:0.6316,f1score:0.7273,roc:0.7855,tn=31,fp=2,fn=7,tp=12"

# %%
mobis1 = "colsample_bytree=0.4, learning_rate=0.02, max_delta_step=0.8, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=450, num_leaves=3, objective='binary', \
               random_state=42, scale_pos_weight=2, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.4, learning_rate: 0.02,  \
                  max_delta_step: 0.8, max_depth: None, metric: 'binary_logloss',  \
                  n_estimators: None, num_iterations: 450, num_leaves: 3,  \
                  objective: 'binary', scale_pos_weight: 2, subsample: None, \
Best Score: 0.7913043478260869, Best Index: 84963, \
train accuracy: 0.9826, val accuracy= 0.8621, test accuracy= 0.7568, \
precision : 0.6667, recall : 0.7143, f1score : 0.6897, roc : 0.7484, \
tn=18   , fp=5, fn=4  , tp=10   "


mobis2 = "colsample_bytree=0.36, learning_rate=0.006, max_delta_step=0.5, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=500, num_leaves=2, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.36,  \
                  learning_rate: 0.006, max_delta_step: 0.5, max_depth: None,  \
                  metric: 'binary_logloss', n_estimators: None, num_iterations: 500,  \
                  num_leaves: 2, objective: 'binary', subsample: None, \
Best Score: 0.8159420289855073, Best Index: 30690, \
train accuracy: 0.8487, val accuracy= 0.7667, test accuracy= 0.7895, \
precision : 0.8182, recall : 0.6000, f1score : 0.6923, roc : 0.7565, \
tn=21  , fp=2, fn=6  , tp=9   "


mobis3 = "colsample_bytree=0.25, learning_rate=0.007, max_delta_step=0.5, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=500, num_leaves=2, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.25, learning_rate: 0.007,  \
                  max_delta_step: 0.5, max_depth: None, metric: 'binary_logloss',  \
                  n_estimators: None, num_iterations: 500, num_leaves: 2,  \
                  objective: 'binary', subsample: None, \
Best Score: 0.7652173913043478, Best Index: 4770, \
train accuracy: 0.8174, val accuracy= 0.8621, test accuracy= 0.7568, \
precision : 1.0000, recall : 0.3571, f1score : 0.5263, roc : 0.6786, \
tn=23   , fp=0, fn=9  , tp=5   "


mobis4 = "colsample_bytree=0.25, learning_rate=0.007, max_delta_step=0.5, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=500, num_leaves=2, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.25, learning_rate: 0.007,  \
                  max_delta_step: 0.5, max_depth: None, metric: 'binary_logloss',  \
                  n_estimators: None, num_iterations: 500, num_leaves: 2,  \
                  objective: 'binary', subsample: None, \
Best Score: 0.7652173913043478, Best Index: 18585, \
train accuracy: 0.8174, val accuracy= 0.8621, test accuracy= 0.7568, \
precision : 1.0000, recall : 0.3571, f1score : 0.5263, roc : 0.6786, \
tn=23   , fp=0, fn=9  , tp= 5  "

mobis5 = "colsample_bytree=0.25, learning_rate=0.007, max_delta_step=0.5, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=500, num_leaves=2, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.25, learning_rate: 0.007,  \
                  max_delta_step: 0.5, max_depth: None, metric: 'binary_logloss',  \
                  n_estimators: None, num_iterations: 500, num_leaves: 2,  \
                  objective: 'binary', subsample: None, \
Best Score: 0.7652173913043478, Best Index: 18585, \
train accuracy: 0.8174, val accuracy= 0.8621, test accuracy= 0.7568, \
precision : 1.0000, recall : 0.3571, f1score : 0.5263, roc : 0.6786, \
tn=23   , fp=0, fn=9  , tp=5   "


mobis6 = "colsample_bytree=0.25, learning_rate=0.008, max_delta_step=0.7, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=500, num_leaves=4, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.25, learning_rate: 0.008,  \
                  max_delta_step: 0.7, max_depth: None, metric: 'binary_logloss',  \
                  n_estimators: None, num_iterations: 500, num_leaves: 4,  \
                  objective: 'binary', subsample: None, \
Best Score: 0.773913043478261, Best Index: 20319, \
train accuracy: 0.9217, val accuracy= 0.8966, test accuracy= 0.7027, \, \
precision : 0.7143, recall : 0.3571, f1score : 0.4762, roc : 0.6351, \
tn=21   , fp=2, fn=9  , tp=5   "


mobis7 = "colsample_bytree=0.35, learning_rate=0.01, max_delta_step=0.8, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=550, num_leaves=4, objective='binary', \
               random_state=42, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.35, learning_rate: 0.01,  \
                  max_delta_step: 0.8, max_depth: None, metric: 'binary_logloss',  \
                  n_estimators: None, num_iterations: 550, num_leaves: 4,  \
                  objective: 'binary', subsample: None, \
Best Score: 0.7826086956521741, Best Index: 106596, \
train accuracy: 0.9826, val accuracy= 0.8966, test accuracy= 0.7568, \
precision : 0.7273, recall : 0.5714, f1score : 0.6400, roc : 0.7205, \
tn=20   , fp=3, fn=6  , tp=8   "


mobis8 = "colsample_bytree=0.4, learning_rate=0.02, max_delta_step=0.8, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=450, num_leaves=3, objective='binary', \
               random_state=42, scale_pos_weight=2, subsample=None, \
boosting_type: 'gbdt', colsample_bytree: 0.4, learning_rate: 0.02,  \
                  max_delta_step: 0.8, max_depth: None, metric: 'binary_logloss', \
                  n_estimators: None, num_iterations: 450, num_leaves: 3,  \
                  objective: 'binary', scale_pos_weight: 2, subsample: None, \
Best Score: 0.7913043478260869, Best Index: 84963, \
train accuracy: 0.9826, val accuracy= 0.8621, test accuracy= 0.7568, \
precision : 0.6667, recall : 0.7143, f1score : 0.6897, roc : 0.7484, \
tn=18   , fp=5, fn=4  , tp=10   "

# %%
for i in range(1, 9, 1):
    globals()[f'mobis{i}_nospace'] = globals()[f'mobis{i}'].replace(" ","")

# %%
mobis8_nospace
# Out:
# "colsample_bytree=0.4,learning_rate=0.02,max_delta_step=0.8,max_depth=None,metric='binary_logloss',n_estimators=None,num_iterations=450,num_leaves=3,objective='binary',random_state=42,scale_pos_weight=2,subsample=None,boosting_type:'gbdt',colsample_bytree:0.4,learning_rate:0.02,max_delta_step:0.8,max_depth:None,metric:'binary_logloss',n_estimators:None,num_iterations:450,num_leaves:3,objective:'binary',scale_pos_weight:2,subsample:None,BestScore:0.7913043478260869,BestIndex:84963,trainaccuracy:0.9826,valaccuracy=0.8621,testaccuracy=0.7568,precision:0.6667,recall:0.7143,f1score:0.6897,roc:0.7484,tn=18,fp=5,fn=4,tp=10"

# %%
def make_df_from_results(data):
    df = pd.DataFrame(data.split(","), columns=['var'])
    df['var1'] = df['var'].str.replace(":", "=")
    df['var2'] = df['var1'].str.split("=")
    df['param'] = df['var2'].str[0]
    df['value'] = df['var2'].str[1]
    df.drop_duplicates(subset=['param'], keep='last', inplace=True)
    df1 = df[['param', 'value']].set_index('param')
    return df1

# %%
df_base = pd.DataFrame(pd.Series([],dtype=pd.StringDtype(), name='param')).set_index('param')
for i in range(1, 13, 1):
    df_new = make_df_from_results(globals()[f'sec{i}_nospace'])
    df_new.columns = [f'value{i}']
    df_base = pd.merge(df_base,df_new, how='outer', left_index=True, right_index=True) #

# %%
df_base
# Out:
#                   value1              value2              value3  \
# param
#
# eature_fraction     0.8                 NaN                 NaN
# 'num_iterations'     NaN                 NaN                 NaN
# BestIndex            NaN                   0                 726
# BestScore            NaN  0.9333333333333332  0.8375180375180376
# \num_iterations      NaN                 NaN                 NaN
# bagging_fraction     0.9                 NaN                 0.9
# boosting_type        NaN              'gbdt'              'gbdt'
# colsample_bytree     NaN                0.41                 0.5
# eval_metric          NaN           'logloss'                 NaN
# f1score           0.7778              0.3810              0.7059
# feature_fraction     NaN                 NaN                 0.8
# fn                     3                  13                   5
# fp                     5                   0                   5
# learning_rate        NaN               0.004                0.05
# max_delta_step       NaN                 0.5                 0.5
# max_depth            NaN                   2                   2
# metric               NaN              'loss'               'auc'
# n_estimators         NaN                   5                 100
# num_iterations       NaN                 500                 500
# num_leaves           NaN                   3                   4
# objective            NaN            'binary'            'binary'
# precision         0.7368              1.0000              0.7059
# random_state         NaN                  42                  42
# recall            0.8235              0.2353              0.7059
# roc               0.8442              0.6176              0.7854
# subsample            NaN               0.005                 0.5
# testaccuracy      0.8519              0.7593              0.8148
# tn                    32                  37                  32
# tp                    14                   4                  12
# trainaccuracy     1.0000              0.8081              1.0000
# valaccuracy       0.7907              0.7442              0.7907
#
#                               value4              value5              value6  \
# param
#
# eature_fraction                 NaN                 NaN                 NaN
# 'num_iterations'                 NaN                 NaN                 NaN
# BestIndex                        915                 315                7605
# BestScore         0.8377777777777778  0.8377777777777778  0.8342857142857143
# \num_iterations                  NaN                 NaN                 NaN
# bagging_fraction                 0.9                 0.9                 NaN
# boosting_type                 'gbdt'              'gbdt'              'gbdt'
# colsample_bytree                 0.3                 0.1                 0.4
# eval_metric                      NaN                 NaN                 NaN
# f1score                       0.7778              0.7778              0.8108
# feature_fraction                 0.8                 0.8                 NaN
# fn                                 3                   3                   2
# fp                                 5                   5                   5
# learning_rate                    0.1                0.07                0.03
# max_delta_step                   0.5                 0.5                 0.5
# max_depth                          4                   5                   3
# metric                        'rmse'              'rmse'              'loss'
# n_estimators                      80                  50                  30
# num_iterations                   500                 500                 500
# num_leaves                         6                   6                   4
# objective                   'binary'            'binary'            'binary'
# precision                     0.7368              0.7368              0.7500
# random_state                      42                  42                  42
# recall                        0.8235              0.8235              0.8824
# roc                           0.8442              0.8442              0.8736
# subsample                        0.3                 0.1                 0.1
# testaccuracy                  0.8519              0.8519              0.8704
# tn                                32                  32                  32
# tp                                14                  14                  15
# trainaccuracy                 1.0000              1.0000              1.0000
# valaccuracy                   0.7907              0.8140              0.7907
#
#                      value7              value8              value9  \
# param
#
# eature_fraction        NaN                 NaN                 NaN
# 'num_iterations'        100                 NaN                 NaN
# BestIndex              1204                1800                 144
# BestScore               1.0  0.8638888888888889  0.9333333333333332
# \num_iterations         NaN                 NaN                 NaN
# bagging_fraction        NaN                 NaN                 NaN
# boosting_type        'gbdt'              'gbdt'              'gbdt'
# colsample_bytree       0.35                0.45                 0.4
# eval_metric       'logloss'           'logloss'           'logloss'
# f1score              0.1111              0.7500              0.3810
# feature_fraction        NaN                 NaN                 NaN
# fn                       16                   5                  13
# fp                        0                   3                   0
# learning_rate          0.02                0.01                0.01
# max_delta_step          0.5                 0.5                 0.5
# max_depth                 3                   2                   2
# metric               'loss'              'loss'              'loss'
# n_estimators             10                  10                   5
# num_iterations          100                 300                 200
# num_leaves                4                   3                   3
# objective          'binary'            'binary'            'binary'
# precision            1.0000              0.8000              1.0000
# random_state             42                  42                  42
# recall               0.0588              0.7059              0.2353
# roc                  0.5294              0.8124              0.6176
# subsample              0.05                0.05                0.03
# testaccuracy         0.7037              0.8519              0.7593
# tn                       37                  34                  37
# tp                        1                  12                   4
# trainaccuracy        0.7849              0.9128              0.8023
# valaccuracy          0.7442              0.8140              0.7442
#
#                              value10             value11             value12
# param
#
# eature_fraction                 NaN                 NaN                 NaN
# 'num_iterations'                 NaN                 NaN                 NaN
# BestIndex                        720                 432                   0
# BestScore         0.8638888888888889  0.8355555555555556  0.9333333333333332
# \num_iterations                  300                 NaN                 NaN
# bagging_fraction                 NaN                 NaN                 NaN
# boosting_type                 'gbdt'              'gbdt'              'gbdt'
# colsample_bytree                0.42                0.42                0.41
# eval_metric                'logloss'           'logloss'           'logloss'
# f1score                       0.7500              0.7333              0.3810
# feature_fraction                 NaN                 NaN                 NaN
# fn                                 5                   6                  13
# fp                                 3                   2                   0
# learning_rate                   0.01               0.005               0.004
# max_delta_step                   0.5                 0.5                 0.5
# max_depth                          2                   2                   2
# metric                        'loss'              'loss'              'loss'
# n_estimators                       5                   5                   5
# num_iterations                   NaN                 500                 500
# num_leaves                         3                   3                   3
# objective                   'binary'            'binary'            'binary'
# precision                     0.8000              0.8462              1.0000
# random_state                      42                  42                  42
# recall                        0.7059              0.6471              0.2353
# roc                           0.8124              0.7965              0.6176
# subsample                       0.03                0.01               0.005
# testaccuracy                  0.8519              0.8519              0.7593
# tn                                34                  35                  37
# tp                                12                  11                   4
# trainaccuracy                 0.9070              0.8895              0.8081
# valaccuracy                   0.8140              0.8372              0.7442

# %%
total = pd.concat([investor_rate, historical_rate, date_weekday, df_o ], axis=1)
# Out:
#                                value
# param
# eval_metric                'logloss'
# max_delta_step                   0.5
# num_iterations                   500
# random_state                      42
# boosting_type                 'gbdt'
# colsample_bytree                0.41
# learning_rate                  0.004
# max_depth                          2
# metric                        'loss'
# n_estimators                       5
# num_leaves                         3
# objective                   'binary'
# subsample                      0.005
# BestScore         0.9333333333333332
# BestIndex                          0
# trainaccuracy                 0.8081
# valaccuracy                   0.7442
# testaccuracy                  0.7593
# precision                     1.0000
# recall                        0.2353
# f1score                       0.3810
# roc                           0.6176
# tn                                37
# fp                                 0
# fn                                13
# tp                                 4

# %%
df_base = pd.DataFrame(pd.Series([],dtype=pd.StringDtype(), name='param')).set_index('param')

# %%
df_base = pd.DataFrame(pd.Series(, name='date')).set_index('date')

# %%
    df_base = df_base.merge(df_temp.set_index('date').iloc[:, [-1]], \
                            how='left', left_index=True, right_index=True)

# %%
df_base = df_base.merge(df2, how='left', left_index=True, right_index=True)

# %%
df_new.drop_duplicates(subset=['param'], keep='last')

# %%
df_base
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame(sec12_nospace.split(","), columns=['var'])

# %%
df['var1'] = df['var'].str.replace(":", "=")
df['var2'] = df['var1'].str.split("=")
df['param'] = df['var2'].str[0]
df['value'] = df['var2'].str[1]
df1 = df[['param', 'value']]

# %%
df
# Out:
#                              var                          var1  \
# 0          colsample_bytree=0.41         colsample_bytree=0.41
# 1          eval_metric='logloss'         eval_metric='logloss'
# 2            learning_rate=0.004           learning_rate=0.004
# 3             max_delta_step=0.5            max_delta_step=0.5
# 4                    max_depth=2                   max_depth=2
# 5                  metric='loss'                 metric='loss'
# 6                 n_estimators=5                n_estimators=5
# 7             num_iterations=500            num_iterations=500
# 8                   num_leaves=3                  num_leaves=3
# 9             objective='binary'            objective='binary'
# 10               random_state=42               random_state=42
# 11               subsample=0.005               subsample=0.005
# 12          boosting_type:'gbdt'          boosting_type='gbdt'
# 13         colsample_bytree:0.41         colsample_bytree=0.41
# 14           learning_rate:0.004           learning_rate=0.004
# 15                   max_depth:2                   max_depth=2
# 16                 metric:'loss'                 metric='loss'
# 17                n_estimators:5                n_estimators=5
# 18                  num_leaves:3                  num_leaves=3
# 19            objective:'binary'            objective='binary'
# 20               subsample:0.005               subsample=0.005
# 21  BestScore:0.9333333333333332  BestScore=0.9333333333333332
# 22                   BestIndex:0                   BestIndex=0
# 23          trainaccuracy:0.8081          trainaccuracy=0.8081
# 24            valaccuracy=0.7442            valaccuracy=0.7442
# 25           testaccuracy=0.7593           testaccuracy=0.7593
# 26              precision:1.0000              precision=1.0000
# 27                 recall:0.2353                 recall=0.2353
# 28                f1score:0.3810                f1score=0.3810
# 29                    roc:0.6176                    roc=0.6176
# 30                         tn=37                         tn=37
# 31                          fp=0                          fp=0
# 32                         fn=13                         fn=13
# 33                          tp=4                          tp=4
#
#                                var2             param               value
# 0          [colsample_bytree, 0.41]  colsample_bytree                0.41
# 1          [eval_metric, 'logloss']       eval_metric           'logloss'
# 2            [learning_rate, 0.004]     learning_rate               0.004
# 3             [max_delta_step, 0.5]    max_delta_step                 0.5
# 4                    [max_depth, 2]         max_depth                   2
# 5                  [metric, 'loss']            metric              'loss'
# 6                 [n_estimators, 5]      n_estimators                   5
# 7             [num_iterations, 500]    num_iterations                 500
# 8                   [num_leaves, 3]        num_leaves                   3
# 9             [objective, 'binary']         objective            'binary'
# 10               [random_state, 42]      random_state                  42
# 11               [subsample, 0.005]         subsample               0.005
# 12          [boosting_type, 'gbdt']     boosting_type              'gbdt'
# 13         [colsample_bytree, 0.41]  colsample_bytree                0.41
# 14           [learning_rate, 0.004]     learning_rate               0.004
# 15                   [max_depth, 2]         max_depth                   2
# 16                 [metric, 'loss']            metric              'loss'
# 17                [n_estimators, 5]      n_estimators                   5
# 18                  [num_leaves, 3]        num_leaves                   3
# 19            [objective, 'binary']         objective            'binary'
# 20               [subsample, 0.005]         subsample               0.005
# 21  [BestScore, 0.9333333333333332]         BestScore  0.9333333333333332
# 22                   [BestIndex, 0]         BestIndex                   0
# 23          [trainaccuracy, 0.8081]     trainaccuracy              0.8081
# 24            [valaccuracy, 0.7442]       valaccuracy              0.7442
# 25           [testaccuracy, 0.7593]      testaccuracy              0.7593
# 26              [precision, 1.0000]         precision              1.0000
# 27                 [recall, 0.2353]            recall              0.2353
# 28                [f1score, 0.3810]           f1score              0.3810
# 29                    [roc, 0.6176]               roc              0.6176
# 30                         [tn, 37]                tn                  37
# 31                          [fp, 0]                fp                   0
# 32                         [fn, 13]                fn                  13
# 33                          [tp, 4]                tp                   4

# %%
a = "colsample_bytree=0.4, learning_rate=0.02, max_delta_step=0.8, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=450, num_leaves=3, objective='binary', \
               random_state=42, scale_pos_weight=2, subsample=None"

# %%
np.array(a.split(", ")).replace(" ", "")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.array(a.split(", ")).replace(" ", "")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'replace'

# %%
a.split(", ")
# Out:
# ['colsample_bytree=0.4',
#  'learning_rate=0.02',
#  'max_delta_step=0.8',
#  '               max_depth=None',
#  "metric='binary_logloss'",
#  'n_estimators=None',
#  '               num_iterations=450',
#  'num_leaves=3',
#  "objective='binary'",
#  '               random_state=42',
#  'scale_pos_weight=2',
#  'subsample=None']

# %%
np.array([1,2]).
# Out:
# array([1, 2])

# %%
import pandas as pd

# %%
df = pd.DataFrame(a.split(", "), columns=['var'])

# %%
df['var1'] = df['var'].str.split("=").str[0]
df['var2'] = df['var'].str.split("=").str[1]

# %%
df
# Out:
#                                   var                           var1  \
# 0                colsample_bytree=0.4               colsample_bytree
# 1                  learning_rate=0.02                  learning_rate
# 2                  max_delta_step=0.8                 max_delta_step
# 3                      max_depth=None                      max_depth
# 4             metric='binary_logloss'                         metric
# 5                   n_estimators=None                   n_estimators
# 6                  num_iterations=450                 num_iterations
# 7                        num_leaves=3                     num_leaves
# 8                  objective='binary'                      objective
# 9                     random_state=42                   random_state
# 10                 scale_pos_weight=2               scale_pos_weight
# 11                     subsample=None                      subsample
#
#                 var2
# 0                0.4
# 1               0.02
# 2                0.8
# 3               None
# 4   'binary_logloss'
# 5               None
# 6                450
# 7                  3
# 8           'binary'
# 9                 42
# 10                 2
# 11              None

# %%
df['var'] = df['var'].str.split("=")
df
# Out:
#                                      var
# 0                [colsample_bytree, 0.4]
# 1                  [learning_rate, 0.02]
# 2                  [max_delta_step, 0.8]
# 3       [               max_depth, None]
# 4             [metric, 'binary_logloss']
# 5                   [n_estimators, None]
# 6   [               num_iterations, 450]
# 7                        [num_leaves, 3]
# 8                  [objective, 'binary']
# 9      [               random_state, 42]
# 10                 [scale_pos_weight, 2]
# 11                     [subsample, None]

# %%
df['var1'] = df['var'].str[0]
df['var2'] = df['var'].str[1]

# %%
df
# Out:
#                                      var                           var1  \
# 0                [colsample_bytree, 0.4]               colsample_bytree
# 1                  [learning_rate, 0.02]                  learning_rate
# 2                  [max_delta_step, 0.8]                 max_delta_step
# 3       [               max_depth, None]                      max_depth
# 4             [metric, 'binary_logloss']                         metric
# 5                   [n_estimators, None]                   n_estimators
# 6   [               num_iterations, 450]                 num_iterations
# 7                        [num_leaves, 3]                     num_leaves
# 8                  [objective, 'binary']                      objective
# 9      [               random_state, 42]                   random_state
# 10                 [scale_pos_weight, 2]               scale_pos_weight
# 11                     [subsample, None]                      subsample
#
#                 var2
# 0                0.4
# 1               0.02
# 2                0.8
# 3               None
# 4   'binary_logloss'
# 5               None
# 6                450
# 7                  3
# 8           'binary'
# 9                 42
# 10                 2
# 11              None

# %%
df['new_column'] = df['codes'].str[0]

# %%
df['new_column'] = [l[0] if len(l) > 0 else np.nan for l in df['codes']]

# %%
b = "colsample_bytree=0.4, learning_rate=0.02, max_delta_step=0.8, \
               max_depth=None, metric='binary_logloss', n_estimators=None, \
               num_iterations=450, num_leaves=3, objective='binary', \
               random_state=42, scale_pos_weight=2, subsample=None, \
'boosting_type': 'gbdt', 'colsample_bytree': 0.4, 'learning_rate': 0.02, 'max_delta_step': 0.8, \
                'max_depth': None, 'metric': 'binary_logloss', 'n_estimators': None, \
                'num_iterations': 450, 'num_leaves': 3, 'objective': 'binary', \
                'scale_pos_weight': 2, 'subsample': None, \
Best Score: 0.7913043478260869, Best Index: 84963, \
train accuracy: 0.9826, val accuracy= 0.8621, test accuracy= 0.7568, \
precision : 0.6667, recall : 0.7143, f1score : 0.6897, roc : 0.7484, \
tn= 18, fp=5, fn=4, tp=10"

# %%
df['var1'] = df['var'].str.replace(":", "=")

# %%
df['var2'] = df['var1'].str.split("=")

# %%
df['param'] = df['var2'].str[0]
df['value'] = df['var2'].str[1]

# %%
df1 = df[['param', 'value']]

# %%
df1
# Out:
#                                  param                value
# 0                     colsample_bytree                  0.4
# 1                        learning_rate                 0.02
# 2                       max_delta_step                  0.8
# 3                            max_depth                 None
# 4                               metric     'binary_logloss'
# 5                         n_estimators                 None
# 6                       num_iterations                  450
# 7                           num_leaves                    3
# 8                            objective             'binary'
# 9                         random_state                   42
# 10                    scale_pos_weight                    2
# 11                           subsample                 None
# 12                     'boosting_type'               'gbdt'
# 13                  'colsample_bytree'                  0.4
# 14                     'learning_rate'                 0.02
# 15                    'max_delta_step'                  0.8
# 16                         'max_depth'                 None
# 17                            'metric'     'binary_logloss'
# 18                      'n_estimators'                 None
# 19                    'num_iterations'                  450
# 20                        'num_leaves'                    3
# 21                         'objective'             'binary'
# 22                  'scale_pos_weight'                    2
# 23                         'subsample'                 None
# 24                          Best Score   0.7913043478260869
# 25                          Best Index                84963
# 26                      train accuracy               0.9826
# 27                        val accuracy               0.8621
# 28                       test accuracy               0.7568
# 29                          precision                0.6667
# 30                             recall                0.7143
# 31                            f1score                0.6897
# 32                                roc                0.7484
# 33                                  tn                   18
# 34                                  fp                    5
# 35                                  fn                    4
# 36                                  tp                   10

# %% [markdown]
# <a href="https://colab.research.google.com/github/fasthill/ML-DL-study-alone/blob/main/5-1%20%EA%B2%B0%EC%A0%95%20%ED%8A%B8%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analyse from LightGBM

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/5-1.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
import datetime
import os, re

# %%
from xgboost import XGBClassifier
import xgboost
from lightgbm import LGBMClassifier
import lightgbm
import joblib

# %%
from skopt import BayesSearchCV
# parameter ranges are specified by one of below
from skopt.space import Real, Categorical, Integer

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier, SGDRegressor
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer

from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import pickle

# write list, dictionary to pickle
def save_to_pickle(path, filename):
    open_file = open(path, "wb")
    pickle.dump(filename, open_file)
    open_file.close()

# read list, dictionary from pickle
def load_from_pickle(path):
    open_file = open(path, "rb")
    loaded_file = pickle.load(open_file)
    open_file.close()
    return loaded_file

# %%
import csv

# write list, dictionary to csv
# path = './xxx/', my_dict = filename

def save_dict_to_csv(path, my_dict):
    df = pd.DataFrame.from_dict(my_dict, orient='index') 
    df.to_csv (path, index=False, header=True)  
    
def save_list_to_csv(path, my_list):
    df = pd.DataFrame(my_list, columns=['columns'])
    df.to_csv (path, index=False, header=True) 
    
# def load_dict_from_csv(path):
#     df = pd.read_csv(path, header=None)
#     my_dict = df.to_dict()
#     return my_dict

# %%
def predict_p(test_target, y_predict_list): 
    ps = precision_score(test_target, y_predict_list)
    rs = recall_score(test_target, y_predict_list)
    fs = f1_score(test_target, y_predict_list)
    roc = roc_auc_score(test_target, y_predict_list)
    collect_list = [ps, rs, fs, roc]
    return collect_list

# %%
def make_df_from_estimator(estimator, num):
    df_t = pd.DataFrame.from_dict(estimator, orient='index')
    df_t.columns = [f'value{num}']
    df_t.index.name = 'parameter'
    return df_t

# %%
def calc_results(lgbm, model, train_scaled, val_scaled, test_scaled, train_target, val_target, test_target,
                 test_scaled1, test_scaled2, test_scaled3, test_target1, test_target2, test_target3):
# model = lgbmgs.best_estimator_  # 최적의 파라미터로 모델 생성
    y_predict = model.predict(test_scaled)
    result_dict= {}
#     result_dict['best_score'] = lgbmgs.best_score_ 
#     result_dict['best_index'] = lgbmgs.best_index_
    result_dict['best_score'] = lgbm.best_score_ 
    result_dict['best_index'] = lgbm.best_index_
    result_dict['acc_train'] = model.score(train_scaled, train_target)
    result_dict['acc_val'] = model.score(val_scaled, val_target)
    result_dict['acc_test'] = model.score(test_scaled, test_target)
    result_dict['precision'] = precision_score(test_target, y_predict)
    result_dict['recall'] = recall_score(test_target, y_predict)
    result_dict['f1score'] = f1_score(test_target, y_predict)
    result_dict['roc'] = roc_auc_score(test_target, y_predict)
    cm = confusion_matrix(test_target, y_predict)
    result_dict['tn'] = cm[0,0]
    result_dict['fp'] = cm[0,1]
    result_dict['fn'] = cm[1,0]
    result_dict['tp'] = cm[1,1]
    #------------------------------------
    y_predict = model.predict(test_scaled1)
    result_dict['acc_test1'] = model.score(test_scaled1, test_target1)
    result_dict['precision1'] = precision_score(test_target1, y_predict)
    result_dict['recall1'] = recall_score(test_target1, y_predict)
    result_dict['f1score1'] = f1_score(test_target1, y_predict)
    result_dict['roc1'] = roc_auc_score(test_target1, y_predict)
    cm = confusion_matrix(test_target1, y_predict)
    result_dict['tn1'] = cm[0,0]
    result_dict['fp1'] = cm[0,1]
    result_dict['fn1'] = cm[1,0]
    result_dict['tp1'] = cm[1,1]
    #------------------------------------
    y_predict = model.predict(test_scaled2)
    result_dict['acc_test2'] = model.score(test_scaled2, test_target2)
    result_dict['precision2'] = precision_score(test_target2, y_predict)
    result_dict['recall2'] = recall_score(test_target2, y_predict)
    result_dict['f1score2'] = f1_score(test_target2, y_predict)
    result_dict['roc2'] = roc_auc_score(test_target2, y_predict)
    cm = confusion_matrix(test_target2, y_predict)
    result_dict['tn2'] = cm[0,0]
    result_dict['fp2'] = cm[0,1]
    result_dict['fn2'] = cm[1,0]
    result_dict['tp2'] = cm[1,1]
    #------------------------------------
    y_predict = model.predict(test_scaled3)
    result_dict['acc_test3'] = model.score(test_scaled3, test_target3)
    result_dict['precision3'] = precision_score(test_target3, y_predict)
    result_dict['recall3'] = recall_score(test_target3, y_predict)
    result_dict['f1score3'] = f1_score(test_target3, y_predict)
    result_dict['roc3'] = roc_auc_score(test_target3, y_predict)
    cm = confusion_matrix(test_target3, y_predict)
    result_dict['tn3'] = cm[0,0]
    result_dict['fp3'] = cm[0,1]
    result_dict['fn3'] = cm[1,0]
    result_dict['tp3'] = cm[1,1]
    return result_dict

# %%
# save parameters and columns used for the analysis
def save_parameters(iter, com_name, dt, precision, params_o, new_col):
    save_to_pickle(f'./{com_name}/params_{dt}_{round(precision*100):2d}%_ver{iter}.pkl', params_o)
    save_dict_to_csv(f'./{com_name}/params_{dt}_{round(precision*100):2d}%_ver{iter}.csv', params_o)
    save_to_pickle(f'./{com_name}/columns_{dt}_{len(new_col)}_{round(precision*100):2d}%_ver{iter}.pkl', new_col)
    save_list_to_csv(f'./{com_name}/columns_{dt}_{len(new_col)}_{round(precision*100):2d}%_ver{iter}.csv', new_col)

# %%
code = {'005930' : ['삼성전자', 'sec'], '373220' : ['LG에너지솔루션', 'lgenergy'], 
        '000660' : ['SK하이닉스', 'skhinix'], '207940' : ['삼성바이오로직스', 'ssbio'],
        '006400' : ['삼성SDI', 'sdi'], '051910' : ['LG화학', 'lgchemical'],
        '005935' : ['삼성전자우', 'secpre'], '005380' : ['현대차', 'hyunmotor'],
        '035420' : ['NAVER', 'naver'], '000270' : ['기아','kia'],
        '035720' : ['카카오', 'kakao'], '005490' : ['POSCO홀딩스', 'poscoholding'],
        '105560' : ['KB금융', 'kbbank'], '028260' : ['삼성물산', 'sscnt'],
        '068270' : ['셀트리온', 'celltrion'], '012330' : ['현대모비스', 'mobis'],
        '055550' : ['신한지주', 'shgroup'], '066570' : ['LG전자', 'lgelec'],
        '003670' : ['포스코케미칼', 'poscochemical'], '096770' : ['SK이노베이션', 'skinnovation'],
        '033780' : ['KT&G', 'ktng']}

code = {'005930' : ['삼성전자', 'sec']}

# %%
col_inv1 = ['retail_1', 'foreigner_1', 'institution_1', 'financial_1', 'invtrust_1', 'pension_1', 
#             'privequity_1', 'bank_1', 'insurance_1', 'financeetc_1', 'corporateetc_1', 
            'privequity_1',  'insurance_1', 'corporateetc_1', # bank_1, 'financeetc_1 제외
            'foreigneretc_1']
col_inv2 = ['retail_2', 'foreigner_2', 'institution_2', 'financial_2', 'invtrust_2', 'pension_2',
#             'privequity_2', 'bank_2', 'insurance_2', 'financeetc_2', 'corporateetc_2', 
            'privequity_2', 'insurance_2', 'corporateetc_2', # bank_2, 'financeetc_2 제외
            'foreigneretc_2']
col_his1 = ['open_1', 'high_1', 'low_1', 'close_1', 'vol_1']
col_his2 = ['open_2', 'high_2', 'low_2', 'close_2', 'vol_2']
col_cr = ['weekday', 'cr_00', 'cr_05', 'cr_10', 'cr_15', 'cr_20']
col_common1 = ["dji_cr", "dji_f_cr", "dxy_cr", "ixic_f_cr", "bond_kor_10_cr", "bond_kor_2_cr", "kosdaq_cr", "kospi_cr", 
         "krw_cr", "ixic_cr", "spx_f_cr", "sox_cr", "spx_cr", "bond_usa_10_cr", "bond_usa_2_cr", "bond_usa_3m_cr", 
         "vix_cr", "wti_cr", "spsy_cr", "spny_cr", "spxhc_cr", "splrcd_cr", "splrci_cr", "splrcu_cr", "splrcs_cr",
         "splrct_cr", "splrcl_cr", "splrcm_cr", "ixbk_cr", "ixfn_cr", "ixid_cr", "ixis_cr", "ixk_cr", "ixtr_cr",
         "ixut_cr", "nbi_cr", "bkx_cr"]
col_common2 = ["dji_cr_2", "dji_f_cr_2", "dxy_cr_2", "ixic_f_cr_2", "bond_kor_10_cr_2", "bond_kor_2_cr_2", "kosdaq_cr_2", "kospi_cr_2",
         "krw_cr_2", "ixic_cr_2", "spx_f_cr_2", "sox_cr_2", "spx_cr_2", "bond_usa_10_cr_2", "bond_usa_2_cr_2", "bond_usa_3m_cr_2",
         "vix_cr_2", "wti_cr_2", "spsy_cr_2", "spny_cr_2", "spxhc_cr_2", "splrcd_cr_2", "splrci_cr_2", "splrcu_cr_2",
         "splrcs_cr_2", "splrct_cr_2", "splrcl_cr_2", "splrcm_cr_2", "ixbk_cr_2", "ixfn_cr_2", "ixid_cr_2",
         "ixis_cr_2", "ixk_cr_2", "ixtr_cr_2", "ixut_cr_2", "nbi_cr_2", "bkx_cr_2"]
new_col = col_inv1 + col_common1 + col_his1 + col_inv2 + col_common2 + col_his2 + col_cr

# bank, financeetc는 결측치가 많아서 사용하지 않음.
# df.drop(['bank_1', 'bank_2', 'financeetc_1', 'financeetc_2'], axis=1, inplace=True)

# %%
# 최초의 empty df 생성
df_base = pd.DataFrame(pd.Series([],dtype=pd.StringDtype(), name='parameter')).set_index('parameter')
iter = 0

# %%
com_name = list(code.values())[0][1]

directory_for_ml = '../data/data_for_ml/expand_date/'
fname = f'df_{com_name}_sel.pkl'
f_name = directory_for_ml + fname
df_o = pd.read_pickle(f_name)

# %%
# 반복 작업시 여기서 부터 진행 (feature importance로 선정된 새로운 column으로)

df = df_o[new_col]  # 새롭게 선정된 column으로 진행

# train, val,: 8, test: 2
split_ratio = 0.8
split_n = int(len(df)*split_ratio)

test_interval = int((len(df) - split_n)/3)
data = df.iloc[:split_n, :-5]
target = df.iloc[:split_n, -5]
test_input = df.iloc[split_n:, :-5]
test_target = df.iloc[split_n:, -5]
test_input1 = df.iloc[split_n:split_n+test_interval, :-5]
test_input2 = df.iloc[split_n+test_interval: split_n+test_interval*2, :-5]
test_input3 = df.iloc[split_n+test_interval*2:, :-5]
test_target1 = df.iloc[split_n:split_n+test_interval, -5]
test_target2 = df.iloc[split_n+test_interval: split_n+test_interval*2, -5]
test_target3 = df.iloc[split_n+test_interval*2:, -5]

train_input, val_input, train_target, val_target = \
     train_test_split(data, target, random_state=42, test_size=0.2, stratify=target)

scaler = StandardScaler()
scaler.fit(train_input)
train_scaled = scaler.transform(train_input)
val_scaled = scaler.transform(val_input)
test_scaled = scaler.transform(test_input)
test_scaled1 = scaler.transform(test_input1)
test_scaled2 = scaler.transform(test_input2)
test_scaled3 = scaler.transform(test_input3)

# %%
param_base = {'boosting_type' : ['gbdt'], # ['gbdt', 'dart', 'goss'], # dart : 신경망의 드롭아웃을 적용시킨 방법, 
              'num_leaves' :  [6, 7, 8,], # 두번째로 중요, num_leaves는 작은 데이터면 작은 숫자로
              'learning_rate' :  [0.001, 0.0015, 0.0017, 0.002, 0.0025],
#               'max_delta_step' :  [0.4, 0.5, 0.6],
              'n_estimators' :  [ 1100, 1200, 1300, 1400],
              'colsample_bytree' :  [ 0.5, 0.6, 0.7, 0.8], # = feature fraction, column sampling. 위의 subsample과 같이 튜닝.
              'subsample' : [1], #  [0.1, 0.2, 0.3, 0.4], # 세번째로 중요. = bagging fraction, row sampling. 아래 colsample_bytree과 같이 튜닝.
              'max_depth' :  [-1], # 가장 먼저 튜닝 필요 -1이 default (무한깊이) 일반적으로 default가 가장 좋음.
              'objective': ['binary'],
              'metric': ['binary_logloss'],
              'scale_pos_weight': [1.0, 1.5, 2], # posiive  증가, class imbalance 경감, scale_pos_weight > 0.0, default=1.0. 
#               'min_child_samples' : [30],
#               'lambda_l1': [0, 5], # default 0
#               'lambda_l2': [0, 5], #default 0
              }

# %%
search_space = {
    'boosting_type' : ['gbdt', 'dart', 'goss'],
    'learning_rate': (0.0005, 0.003, 'log-uniform'),
    'num_leaves': (3, 10),      
    'max_depth': (0, 50), #[-1], #(0, 50),
    'min_child_samples': (10, 40),
#     'max_bin': (100, 1000),
    'subsample': (0.01, 1.0, 'uniform'),
#     'subsample_freq': (0, 10),
    'colsample_bytree': (0.01, 1.0, 'uniform'),
    'subsample_for_bin': (100000, 500000),
#     'scale_pos_weight': np.arange(0.2, 2, 0.1) ,
    'n_estimators': (800, 1500),
#     'reg_alpha' : (0, 4.0, 'uniform'), # =='lambda_l1': [0, 5], # default 0
    'reg_alpha' : np.arange(0, 4, 0.2),
#     'reg_lambda' : (0, 4.0, 'uniform'), # == lambda_l2': [0, 5], #default 0
    'reg_lambda' : np.arange(0, 4, 0.2),
    'force_col_wise': ['true'], 
    'boost_from_average' : [True],
    'objective': ['binary'],
    'metric': ['binary_logloss'],
}

# %%
param_grid = {
    'cv' : 5,
#     'cv' : None,
#     'scoring' : None,
    'scoring' : make_scorer(precision_score, pos_label=1), #'precision',
#     'scoring' : 'accuracy',
    'num_col' : len(new_col),
    'iterations' : 10,
             }

# %%
params_o = param_base.copy()

# %%
# directory가 없으면 만드는 과정
if not os.path.exists(com_name):
    os.makedirs(com_name)
    
while True:
    iter = iter + 1

    lgbm = None
    lgbmgs = None
    lgbmBS = None

    lgbm = lightgbm.LGBMClassifier(random_state=42)

    lgbmgs = GridSearchCV(estimator = lgbm,
                          param_grid = params_o,
#                           cv = 10, # StratifiedKFold us default for binary or multiclass
#                           scoring = 'precision', 
#                           scoring = 'accuracy', 
#                           scoring = ['accuracy', 'precision'], # refit 사용해야 함. 고로 사용하지 않음.
                          cv = param_grid['cv'],
                          scoring = param_grid['scoring'],
                          error_score='raise',
                          verbose = 1,
                          n_jobs=-1, # 자동 검색 적용
                         )
    
    lgbmBS = BayesSearchCV( estimator = lightgbm.LGBMClassifier( objective='binary',
                                                                 metric='precision',
                                                                 n_jobs=-1,
                                                                 verbose=1 ),
                           search_spaces = search_space,
                           scoring = param_grid['scoring'],
#                            scoring=make_scorer(precision_score, pos_label=1),
                           cv = StratifiedKFold( n_splits=param_grid['cv'],
                                                 shuffle=True,
                                                 random_state=42 ),
                           n_jobs = -1, # 자동 검색 적용
                           n_iter = param_grid['iterations'],   
                           verbose = 1, refit = 'precision', random_state = 42,

                          )
                          
    print("*** after lgbmgs ******")
#     lgbmgs.fit(train_scaled, train_target, eval_metric = 'logloss') 
    lgbmBS.fit(train_scaled, train_target, eval_metric = 'logloss') 
#     lgbmgs.fit(train_scaled, train_target, eval_metric = 'logloss', eval_set = (val_scaled, val_target)) 
    # eval_set가 있어야 "early_stopping_rounds"를 사용할 수 있음.

# save model
    stamp = datetime.datetime.today().isoformat() # 파일명 끝에 생성날짜 시간 추가
    dt = re.sub(r'[-:T]', '', stamp[5:16])
    dt = f'{dt[:4]}_{dt[4:]}'
#     joblib.dump(lgbmgs, f'./{com_name}/lgbm_{dt}_v{iter}.pkl') # gridsearchcv 저장
#     joblib.dump(lgbmBS, f'./{com_name}/lgbm_{dt}_v{iter}.pkl') # gridsearchcv 저장
#     joblib.dump(scaler, f'./{com_name}/scaler_{dt}_v{iter}.pkl') # scaler 저장
    
#     df_estimator = make_df_from_estimator(lgbmgs.best_estimator_.get_params(), iter)
#     result_dict = calc_results(lgbmgs, lgbmgs.best_estimator_, 
#                                train_scaled, val_scaled, test_scaled,  
#                                train_target, val_target, test_target,
#                                test_scaled1, test_scaled2, test_scaled3,  
#                                test_target1, test_target2, test_target3
#                               )
    
    df_estimator = make_df_from_estimator(lgbmBS.best_estimator_.get_params(), iter)
    result_dict = calc_results(lgbmBS, lgbmBS.best_estimator_, 
                               train_scaled, val_scaled, test_scaled,  
                               train_target, val_target, test_target,
                               test_scaled1, test_scaled2, test_scaled3,  
                               test_target1, test_target2, test_target3
                              )
    
    df_result = make_df_from_estimator(result_dict, iter)
    df_grid = make_df_from_estimator(param_grid, iter)
    df_concat = pd.concat([df_estimator, df_grid, df_result])

    df_base = pd.merge(df_base,df_concat, how='outer', left_index=True, right_index=True)
    
#  4가지 조건이 만족되면 break하고 완료
    val_test = df_concat.loc['acc_val'].iloc[0]
    acc_test = df_concat.loc['acc_test'].iloc[0]
    precision = df_concat.loc['precision'].iloc[0]
    f1score = df_concat.loc['f1score'].iloc[0]
    
    if (val_test >= 0.75 ) & (acc_test > 0.75) & (precision >= 0.8) & (f1score >= 0.6) :
#         df_base.to_csv(f'./{com_name}/lgbm_df_{dt}_{round(precision*100):2d}%_ver{iter}.csv')
#         df_base.to_pickle(f'./{com_name}/lgbm_df_{dt}_{round(precision*100):2d}%_ver{iter}.pkl')
# #         params_o = make_new_parameter(params_o, df_concat)
#         save_parameters(iter, com_name, dt, precision, params_o, new_col)
        break
    if iter >= 1 : 
#         df_base.to_csv(f'./{com_name}/lgbm_df_{dt}_{round(precision*100):2d}%_ver{iter}.csv')
#         df_base.to_pickle(f'./{com_name}/lgbm_df_{dt}_{round(precision*100):2d}%_ver{iter}.pkl')
# #         params_o = make_new_parameter(params_o, df_concat)
#         save_parameters(iter, com_name, dt, precision, params_o, new_col)
        break
    print("******* No.{}  Process is Done! ********".format(iter))
#     params_o = make_new_parameter(params_o, df_concat)
#     save_parameters(iter, com_name, dt, precision, params_o, new_col)
    
print("**** End of Process ****")
# Out:
# *** after lgbmgs ******
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [LightGBM] [Info] Number of positive: 77, number of negative: 101
# [LightGBM] [Info] Total Bins 6229
# [LightGBM] [Info] Number of data points in the train set: 178, number of used features: 105
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.432584 -> initscore=-0.271315
# [LightGBM] [Info] Start training from score -0.271315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# **** End of Process ****

# %%
df_base.iloc[:, 6:].head(60)
# Out:
#                                                        value7  \
# parameter
# acc_test                                             0.660714
# acc_test1                                            0.666667
# acc_test2                                            0.666667
# acc_test3                                                0.65
# acc_train                                            0.853933
# acc_val                                                   0.6
# best_index                                                0.0
# best_score                                           0.712302
# boost_from_average                                       True
# boosting_type                                            gbdt
# class_weight                                             None
# colsample_bytree                                     0.933539
# cv                                                          5
# f1score                                              0.641509
# f1score1                                                  0.7
# f1score2                                             0.571429
# f1score3                                             0.631579
# fn                                                       17.0
# fn1                                                       6.0
# fn2                                                       6.0
# fn3                                                       5.0
# force_col_wise                                           true
# fp                                                        2.0
# fp1                                                       0.0
# fp2                                                       0.0
# fp3                                                       2.0
# importance_type                                         split
# iterations                                                 10
# learning_rate                                        0.001661
# max_depth                                                  21
# metric                                         binary_logloss
# min_child_samples                                          32
# min_child_weight                                        0.001
# min_split_gain                                            0.0
# n_estimators                                             1013
# n_iter                                                    NaN
# n_jobs                                                     -1
# num_col                                                   110
# num_leaves                                                  8
# objective                                              binary
# precision                                            0.894737
# precision1                                                1.0
# precision2                                                1.0
# precision3                                               0.75
# random_state                                             None
# recall                                                    0.5
# recall1                                              0.538462
# recall2                                                   0.4
# recall3                                              0.545455
# reg_alpha                                                 0.4
# reg_lambda                                                0.6
# roc                                                  0.704545
# roc1                                                 0.769231
# roc2                                                      0.7
# roc3                                                 0.661616
# scoring             make_scorer(precision_score, pos_label=1)
# silent                                                   warn
# subsample                                            0.635775
# subsample_for_bin                                      131156
# subsample_freq                                              0
#
#                                                        value8  \
# parameter
# acc_test                                             0.589286
# acc_test1                                            0.555556
# acc_test2                                            0.611111
# acc_test3                                                 0.6
# acc_train                                            0.848315
# acc_val                                              0.444444
# best_index                                                5.0
# best_score                                           0.702778
# boost_from_average                                       True
# boosting_type                                            dart
# class_weight                                             None
# colsample_bytree                                     0.266732
# cv                                                          5
# f1score                                              0.566038
# f1score1                                             0.636364
# f1score2                                             0.533333
# f1score3                                                  0.5
# fn                                                       19.0
# fn1                                                       6.0
# fn2                                                       6.0
# fn3                                                       7.0
# force_col_wise                                           true
# fp                                                        4.0
# fp1                                                       2.0
# fp2                                                       1.0
# fp3                                                       1.0
# importance_type                                         split
# iterations                                                 10
# learning_rate                                         0.00192
# max_depth                                                  12
# metric                                         binary_logloss
# min_child_samples                                          13
# min_child_weight                                        0.001
# min_split_gain                                            0.0
# n_estimators                                             1032
# n_iter                                                    NaN
# n_jobs                                                     -1
# num_col                                                   110
# num_leaves                                                  8
# objective                                              binary
# precision                                            0.789474
# precision1                                           0.777778
# precision2                                                0.8
# precision3                                                0.8
# random_state                                             None
# recall                                               0.441176
# recall1                                              0.538462
# recall2                                                   0.4
# recall3                                              0.363636
# reg_alpha                                                 1.2
# reg_lambda                                                3.6
# roc                                                  0.629679
# roc1                                                 0.569231
# roc2                                                   0.6375
# roc3                                                 0.626263
# scoring             make_scorer(precision_score, pos_label=1)
# silent                                                   warn
# subsample                                            0.960267
# subsample_for_bin                                      308182
# subsample_freq                                              0
#
#                                                        value9
# parameter
# acc_test                                             0.660714
# acc_test1                                            0.666667
# acc_test2                                            0.666667
# acc_test3                                                0.65
# acc_train                                            0.853933
# acc_val                                                   0.6
# best_index                                                0.0
# best_score                                           0.712302
# boost_from_average                                       True
# boosting_type                                            gbdt
# class_weight                                             None
# colsample_bytree                                     0.933539
# cv                                                          5
# f1score                                              0.641509
# f1score1                                                  0.7
# f1score2                                             0.571429
# f1score3                                             0.631579
# fn                                                       17.0
# fn1                                                       6.0
# fn2                                                       6.0
# fn3                                                       5.0
# force_col_wise                                           true
# fp                                                        2.0
# fp1                                                       0.0
# fp2                                                       0.0
# fp3                                                       2.0
# importance_type                                         split
# iterations                                                 10
# learning_rate                                        0.001661
# max_depth                                                  21
# metric                                         binary_logloss
# min_child_samples                                          32
# min_child_weight                                        0.001
# min_split_gain                                            0.0
# n_estimators                                             1013
# n_iter                                                    NaN
# n_jobs                                                     -1
# num_col                                                   110
# num_leaves                                                  8
# objective                                              binary
# precision                                            0.894737
# precision1                                                1.0
# precision2                                                1.0
# precision3                                               0.75
# random_state                                             None
# recall                                                    0.5
# recall1                                              0.538462
# recall2                                                   0.4
# recall3                                              0.545455
# reg_alpha                                                 0.4
# reg_lambda                                                0.6
# roc                                                  0.704545
# roc1                                                 0.769231
# roc2                                                      0.7
# roc3                                                 0.661616
# scoring             make_scorer(precision_score, pos_label=1)
# silent                                                   warn
# subsample                                            0.635775
# subsample_for_bin                                      131156
# subsample_freq                                              0

# %%
lgbmBS.cv_results_
# Out:
# {'mean_fit_time': array([0.16902676, 0.09130125, 0.07966814, 0.23726773, 0.11799908,
#         0.11055236, 0.11927695, 0.18749371, 0.23370972, 0.26358929,
#         0.07046556, 0.21502509, 0.17091408, 0.2763381 , 0.22041821,
#         0.18984809, 0.14787607, 0.28458872, 0.09469075, 0.22695694]),
#  'std_fit_time': array([0.00756297, 0.00166483, 0.0013131 , 0.01212478, 0.00487549,
#         0.00435806, 0.00568978, 0.00938673, 0.01277339, 0.00305843,
#         0.        , 0.00883278, 0.00688477, 0.01749537, 0.0093566 ,
#         0.01496421, 0.00766248, 0.00730057, 0.00595188, 0.0311792 ]),
#  'mean_score_time': array([0.00010252, 0.        , 0.00217352, 0.00040011, 0.00180058,
#         0.00125484, 0.00166359, 0.00320573, 0.00132174, 0.00257483,
#         0.01646037, 0.00263844, 0.        , 0.        , 0.00211358,
#         0.00110092, 0.00312839, 0.0004674 , 0.00252428, 0.001474  ]),
#  'std_score_time': array([0.00020504, 0.        , 0.00044158, 0.00080023, 0.00040009,
#         0.00050874, 0.00053527, 0.00641146, 0.00109976, 0.00055112,
#         0.00102258, 0.001023  , 0.        , 0.        , 0.00110234,
#         0.00095586, 0.00625677, 0.00093479, 0.00057591, 0.002948  ]),
#  'param_boost_from_average': masked_array(data=[True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     True, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_boosting_type': masked_array(data=['gbdt', 'goss', 'goss', 'dart', 'gbdt', 'goss', 'goss',
#                     'goss', 'gbdt', 'goss', 'gbdt', 'gbdt', 'gbdt', 'dart',
#                     'gbdt', 'gbdt', 'gbdt', 'gbdt', 'goss', 'dart'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_colsample_bytree': masked_array(data=[0.9335393188593556, 0.3103760087853332,
#                     0.11381056696717655, 0.6020666067370067,
#                     0.5313540347564155, 0.17197110685216477,
#                     0.3654327026021899, 0.5015020365607495,
#                     0.8729354091785829, 0.743869916924347,
#                     0.04730957039920305, 0.920149848492857,
#                     0.4385075404593849, 0.5985333200771307,
#                     0.3794448340983056, 1.0, 0.6516385594540004, 1.0,
#                     0.20119973136119246, 1.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_force_col_wise': masked_array(data=['true', 'true', 'true', 'true', 'true', 'true', 'true',
#                     'true', 'true', 'true', 'true', 'true', 'true', 'true',
#                     'true', 'true', 'true', 'true', 'true', 'true'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[0.0016612938916177552, 0.002351755791729486,
#                     0.0007002088049764271, 0.0012763912767437431,
#                     0.0025252456096247645, 0.00209837254257327,
#                     0.0014458317106968825, 0.0008935887340296632,
#                     0.0009896828112718643, 0.0014101274965423404,
#                     0.0025493285676943733, 0.0029165107442369544,
#                     0.0016688239242209106, 0.0014167565256754835,
#                     0.0005535122173010452, 0.002860120224673329,
#                     0.0005021653291086421, 0.0013746005724548295,
#                     0.0008722390974867285, 0.0007836132975516147],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[21, 3, 23, 5, 36, 19, 30, 3, 11, 14, 18, 22, 20, 32,
#                     12, 15, 15, 4, 26, 9],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_metric': masked_array(data=['binary_logloss', 'binary_logloss', 'binary_logloss',
#                     'binary_logloss', 'binary_logloss', 'binary_logloss',
#                     'binary_logloss', 'binary_logloss', 'binary_logloss',
#                     'binary_logloss', 'binary_logloss', 'binary_logloss',
#                     'binary_logloss', 'binary_logloss', 'binary_logloss',
#                     'binary_logloss', 'binary_logloss', 'binary_logloss',
#                     'binary_logloss', 'binary_logloss'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_samples': masked_array(data=[32, 21, 33, 36, 30, 26, 23, 11, 21, 15, 13, 25, 27, 29,
#                     12, 26, 33, 14, 36, 39],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[1013, 1245, 1190, 1438, 1047, 1350, 1314, 1070, 1216,
#                     1426, 1134, 1209, 1449, 1349, 982, 854, 1213, 800,
#                     1355, 1208],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_num_leaves': masked_array(data=[8, 10, 10, 6, 8, 7, 7, 9, 4, 9, 6, 4, 8, 8, 9, 7, 8, 8,
#                     4, 6],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_objective': masked_array(data=['binary', 'binary', 'binary', 'binary', 'binary',
#                     'binary', 'binary', 'binary', 'binary', 'binary',
#                     'binary', 'binary', 'binary', 'binary', 'binary',
#                     'binary', 'binary', 'binary', 'binary', 'binary'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_reg_alpha': masked_array(data=[0.4, 3.8000000000000003, 1.4000000000000001, 3.2,
#                     3.4000000000000004, 2.2, 2.4000000000000004, 2.2, 1.6,
#                     0.0, 0.2, 2.8000000000000003, 2.2, 0.6000000000000001,
#                     0.0, 0.4, 2.8000000000000003, 0.4, 3.2, 2.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_reg_lambda': masked_array(data=[0.6000000000000001, 3.0, 0.8, 2.4000000000000004, 1.0,
#                     0.0, 2.4000000000000004, 2.6, 0.4, 0.8, 0.0, 2.6,
#                     0.6000000000000001, 0.6000000000000001,
#                     0.6000000000000001, 1.4000000000000001, 0.0, 0.8, 1.0,
#                     0.6000000000000001],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_subsample': masked_array(data=[0.6357746718688816, 0.3946396015528638,
#                     0.51445560213579, 0.036023557810653695,
#                     0.2721914943460811, 0.5031916043798332,
#                     0.3525162353863268, 0.08532107526802597,
#                     0.1932757915911235, 0.7267675535162856,
#                     0.36178776398675094, 0.49675735143656924,
#                     0.6214820246522765, 0.08253564464058079,
#                     0.10952254275125156, 0.09186064309023383,
#                     0.7401766677865108, 0.01, 0.6369521159694863, 1.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_subsample_for_bin': masked_array(data=[131156, 342928, 278139, 485880, 207155, 487270, 287406,
#                     209797, 247054, 280957, 490992, 145585, 185646, 100000,
#                     100000, 333459, 408399, 314539, 402627, 479034],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.9335393188593556),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0016612938916177552),
#                ('max_depth', 21),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 32),
#                ('n_estimators', 1013),
#                ('num_leaves', 8),
#                ('objective', 'binary'),
#                ('reg_alpha', 0.4),
#                ('reg_lambda', 0.6000000000000001),
#                ('subsample', 0.6357746718688816),
#                ('subsample_for_bin', 131156)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'goss'),
#                ('colsample_bytree', 0.3103760087853332),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.002351755791729486),
#                ('max_depth', 3),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 21),
#                ('n_estimators', 1245),
#                ('num_leaves', 10),
#                ('objective', 'binary'),
#                ('reg_alpha', 3.8000000000000003),
#                ('reg_lambda', 3.0),
#                ('subsample', 0.3946396015528638),
#                ('subsample_for_bin', 342928)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'goss'),
#                ('colsample_bytree', 0.11381056696717655),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0007002088049764271),
#                ('max_depth', 23),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 33),
#                ('n_estimators', 1190),
#                ('num_leaves', 10),
#                ('objective', 'binary'),
#                ('reg_alpha', 1.4000000000000001),
#                ('reg_lambda', 0.8),
#                ('subsample', 0.51445560213579),
#                ('subsample_for_bin', 278139)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'dart'),
#                ('colsample_bytree', 0.6020666067370067),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0012763912767437431),
#                ('max_depth', 5),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 36),
#                ('n_estimators', 1438),
#                ('num_leaves', 6),
#                ('objective', 'binary'),
#                ('reg_alpha', 3.2),
#                ('reg_lambda', 2.4000000000000004),
#                ('subsample', 0.036023557810653695),
#                ('subsample_for_bin', 485880)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.5313540347564155),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0025252456096247645),
#                ('max_depth', 36),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 30),
#                ('n_estimators', 1047),
#                ('num_leaves', 8),
#                ('objective', 'binary'),
#                ('reg_alpha', 3.4000000000000004),
#                ('reg_lambda', 1.0),
#                ('subsample', 0.2721914943460811),
#                ('subsample_for_bin', 207155)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'goss'),
#                ('colsample_bytree', 0.17197110685216477),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.00209837254257327),
#                ('max_depth', 19),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 26),
#                ('n_estimators', 1350),
#                ('num_leaves', 7),
#                ('objective', 'binary'),
#                ('reg_alpha', 2.2),
#                ('reg_lambda', 0.0),
#                ('subsample', 0.5031916043798332),
#                ('subsample_for_bin', 487270)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'goss'),
#                ('colsample_bytree', 0.3654327026021899),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0014458317106968825),
#                ('max_depth', 30),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 23),
#                ('n_estimators', 1314),
#                ('num_leaves', 7),
#                ('objective', 'binary'),
#                ('reg_alpha', 2.4000000000000004),
#                ('reg_lambda', 2.4000000000000004),
#                ('subsample', 0.3525162353863268),
#                ('subsample_for_bin', 287406)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'goss'),
#                ('colsample_bytree', 0.5015020365607495),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0008935887340296632),
#                ('max_depth', 3),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 11),
#                ('n_estimators', 1070),
#                ('num_leaves', 9),
#                ('objective', 'binary'),
#                ('reg_alpha', 2.2),
#                ('reg_lambda', 2.6),
#                ('subsample', 0.08532107526802597),
#                ('subsample_for_bin', 209797)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.8729354091785829),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0009896828112718643),
#                ('max_depth', 11),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 21),
#                ('n_estimators', 1216),
#                ('num_leaves', 4),
#                ('objective', 'binary'),
#                ('reg_alpha', 1.6),
#                ('reg_lambda', 0.4),
#                ('subsample', 0.1932757915911235),
#                ('subsample_for_bin', 247054)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'goss'),
#                ('colsample_bytree', 0.743869916924347),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0014101274965423404),
#                ('max_depth', 14),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 15),
#                ('n_estimators', 1426),
#                ('num_leaves', 9),
#                ('objective', 'binary'),
#                ('reg_alpha', 0.0),
#                ('reg_lambda', 0.8),
#                ('subsample', 0.7267675535162856),
#                ('subsample_for_bin', 280957)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.04730957039920305),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0025493285676943733),
#                ('max_depth', 18),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 13),
#                ('n_estimators', 1134),
#                ('num_leaves', 6),
#                ('objective', 'binary'),
#                ('reg_alpha', 0.2),
#                ('reg_lambda', 0.0),
#                ('subsample', 0.36178776398675094),
#                ('subsample_for_bin', 490992)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.920149848492857),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0029165107442369544),
#                ('max_depth', 22),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 25),
#                ('n_estimators', 1209),
#                ('num_leaves', 4),
#                ('objective', 'binary'),
#                ('reg_alpha', 2.8000000000000003),
#                ('reg_lambda', 2.6),
#                ('subsample', 0.49675735143656924),
#                ('subsample_for_bin', 145585)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.4385075404593849),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0016688239242209106),
#                ('max_depth', 20),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 27),
#                ('n_estimators', 1449),
#                ('num_leaves', 8),
#                ('objective', 'binary'),
#                ('reg_alpha', 2.2),
#                ('reg_lambda', 0.6000000000000001),
#                ('subsample', 0.6214820246522765),
#                ('subsample_for_bin', 185646)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'dart'),
#                ('colsample_bytree', 0.5985333200771307),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0014167565256754835),
#                ('max_depth', 32),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 29),
#                ('n_estimators', 1349),
#                ('num_leaves', 8),
#                ('objective', 'binary'),
#                ('reg_alpha', 0.6000000000000001),
#                ('reg_lambda', 0.6000000000000001),
#                ('subsample', 0.08253564464058079),
#                ('subsample_for_bin', 100000)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.3794448340983056),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0005535122173010452),
#                ('max_depth', 12),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 12),
#                ('n_estimators', 982),
#                ('num_leaves', 9),
#                ('objective', 'binary'),
#                ('reg_alpha', 0.0),
#                ('reg_lambda', 0.6000000000000001),
#                ('subsample', 0.10952254275125156),
#                ('subsample_for_bin', 100000)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 1.0),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.002860120224673329),
#                ('max_depth', 15),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 26),
#                ('n_estimators', 854),
#                ('num_leaves', 7),
#                ('objective', 'binary'),
#                ('reg_alpha', 0.4),
#                ('reg_lambda', 1.4000000000000001),
#                ('subsample', 0.09186064309023383),
#                ('subsample_for_bin', 333459)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 0.6516385594540004),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0005021653291086421),
#                ('max_depth', 15),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 33),
#                ('n_estimators', 1213),
#                ('num_leaves', 8),
#                ('objective', 'binary'),
#                ('reg_alpha', 2.8000000000000003),
#                ('reg_lambda', 0.0),
#                ('subsample', 0.7401766677865108),
#                ('subsample_for_bin', 408399)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'gbdt'),
#                ('colsample_bytree', 1.0),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0013746005724548295),
#                ('max_depth', 4),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 14),
#                ('n_estimators', 800),
#                ('num_leaves', 8),
#                ('objective', 'binary'),
#                ('reg_alpha', 0.4),
#                ('reg_lambda', 0.8),
#                ('subsample', 0.01),
#                ('subsample_for_bin', 314539)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'goss'),
#                ('colsample_bytree', 0.20119973136119246),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0008722390974867285),
#                ('max_depth', 26),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 36),
#                ('n_estimators', 1355),
#                ('num_leaves', 4),
#                ('objective', 'binary'),
#                ('reg_alpha', 3.2),
#                ('reg_lambda', 1.0),
#                ('subsample', 0.6369521159694863),
#                ('subsample_for_bin', 402627)]),
#   OrderedDict([('boost_from_average', True),
#                ('boosting_type', 'dart'),
#                ('colsample_bytree', 1.0),
#                ('force_col_wise', 'true'),
#                ('learning_rate', 0.0007836132975516147),
#                ('max_depth', 9),
#                ('metric', 'binary_logloss'),
#                ('min_child_samples', 39),
#                ('n_estimators', 1208),
#                ('num_leaves', 6),
#                ('objective', 'binary'),
#                ('reg_alpha', 2.0),
#                ('reg_lambda', 0.6000000000000001),
#                ('subsample', 1.0),
#                ('subsample_for_bin', 479034)])],
#  'split0_test_score': array([0.71428571, 0.55555556, 0.45454545, 0.61111111, 0.625     ,
#         0.46153846, 0.58333333, 0.63636364, 0.66666667, 0.5       ,
#         0.53333333, 0.57142857, 0.5625    , 0.6       , 0.6       ,
#         0.61538462, 0.5       , 0.53846154, 0.54545455, 0.64705882]),
#  'split1_test_score': array([0.88888889, 0.8       , 0.77777778, 0.8       , 0.81818182,
#         0.875     , 0.77777778, 0.875     , 0.8       , 0.8       ,
#         0.9       , 0.77777778, 0.8       , 0.81818182, 0.875     ,
#         0.8       , 0.875     , 0.72727273, 0.875     , 0.75      ]),
#  'split2_test_score': array([0.625     , 0.66666667, 0.61538462, 0.64285714, 0.66666667,
#         0.64285714, 0.64285714, 0.6       , 0.66666667, 0.53846154,
#         0.61538462, 0.66666667, 0.625     , 0.6875    , 0.55555556,
#         0.57142857, 0.64285714, 0.6       , 0.64285714, 0.66666667]),
#  'split3_test_score': array([0.58333333, 0.69230769, 0.69230769, 0.64285714, 0.69230769,
#         0.75      , 0.63636364, 0.61538462, 0.63636364, 0.5       ,
#         0.75      , 0.61538462, 0.76923077, 0.6       , 0.72727273,
#         0.61538462, 0.66666667, 0.4       , 0.69230769, 0.81818182]),
#  'split4_test_score': array([0.75      , 0.76923077, 0.75      , 0.8       , 0.72727273,
#         0.81818182, 0.8       , 0.77777778, 0.72727273, 0.81818182,
#         0.75      , 0.75      , 0.75      , 0.69230769, 0.75      ,
#         0.76923077, 0.85714286, 0.7       , 0.72727273, 0.8       ]),
#  'mean_test_score': array([0.71230159, 0.69675214, 0.65800311, 0.69936508, 0.70588578,
#         0.70951548, 0.68806638, 0.70090521, 0.69939394, 0.63132867,
#         0.70974359, 0.67625153, 0.70134615, 0.6795979 , 0.70156566,
#         0.67428571, 0.70833333, 0.59314685, 0.69657842, 0.73638146]),
#  'std_test_score': array([0.10664198, 0.08576087, 0.11592891, 0.08298172, 0.06531893,
#         0.14612901, 0.08516259, 0.10759148, 0.05833314, 0.14593345,
#         0.12606574, 0.07814207, 0.09144954, 0.08012632, 0.11377235,
#         0.09201838, 0.14095962, 0.11811054, 0.10818414, 0.06893877]),
#  'rank_test_score': array([ 2, 12, 18, 11,  6,  4, 14,  9, 10, 19,  3, 16,  8, 15,  7, 17,  5,
#         20, 13,  1])}

# %%
pd.DataFrame(lgbmBS.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.169027      0.007563         0.000103        0.000205
# 1        0.091301      0.001665         0.000000        0.000000
# 2        0.079668      0.001313         0.002174        0.000442
# 3        0.237268      0.012125         0.000400        0.000800
# 4        0.117999      0.004875         0.001801        0.000400
# 5        0.110552      0.004358         0.001255        0.000509
# 6        0.119277      0.005690         0.001664        0.000535
# 7        0.187494      0.009387         0.003206        0.006411
# 8        0.233710      0.012773         0.001322        0.001100
# 9        0.263589      0.003058         0.002575        0.000551
# 10       0.070466      0.000000         0.016460        0.001023
# 11       0.215025      0.008833         0.002638        0.001023
# 12       0.170914      0.006885         0.000000        0.000000
# 13       0.276338      0.017495         0.000000        0.000000
# 14       0.220418      0.009357         0.002114        0.001102
# 15       0.189848      0.014964         0.001101        0.000956
# 16       0.147876      0.007662         0.003128        0.006257
# 17       0.284589      0.007301         0.000467        0.000935
# 18       0.094691      0.005952         0.002524        0.000576
# 19       0.226957      0.031179         0.001474        0.002948
#
#    param_boost_from_average param_boosting_type param_colsample_bytree  \
# 0                      True                gbdt               0.933539
# 1                      True                goss               0.310376
# 2                      True                goss               0.113811
# 3                      True                dart               0.602067
# 4                      True                gbdt               0.531354
# 5                      True                goss               0.171971
# 6                      True                goss               0.365433
# 7                      True                goss               0.501502
# 8                      True                gbdt               0.872935
# 9                      True                goss                0.74387
# 10                     True                gbdt                0.04731
# 11                     True                gbdt                0.92015
# 12                     True                gbdt               0.438508
# 13                     True                dart               0.598533
# 14                     True                gbdt               0.379445
# 15                     True                gbdt                    1.0
# 16                     True                gbdt               0.651639
# 17                     True                gbdt                    1.0
# 18                     True                goss                 0.2012
# 19                     True                dart                    1.0
#
#    param_force_col_wise param_learning_rate param_max_depth  ...  \
# 0                  true            0.001661              21  ...
# 1                  true            0.002352               3  ...
# 2                  true              0.0007              23  ...
# 3                  true            0.001276               5  ...
# 4                  true            0.002525              36  ...
# 5                  true            0.002098              19  ...
# 6                  true            0.001446              30  ...
# 7                  true            0.000894               3  ...
# 8                  true             0.00099              11  ...
# 9                  true             0.00141              14  ...
# 10                 true            0.002549              18  ...
# 11                 true            0.002917              22  ...
# 12                 true            0.001669              20  ...
# 13                 true            0.001417              32  ...
# 14                 true            0.000554              12  ...
# 15                 true             0.00286              15  ...
# 16                 true            0.000502              15  ...
# 17                 true            0.001375               4  ...
# 18                 true            0.000872              26  ...
# 19                 true            0.000784               9  ...
#
#    param_subsample_for_bin                                             params  \
# 0                   131156  {'boost_from_average': True, 'boosting_type': ...
# 1                   342928  {'boost_from_average': True, 'boosting_type': ...
# 2                   278139  {'boost_from_average': True, 'boosting_type': ...
# 3                   485880  {'boost_from_average': True, 'boosting_type': ...
# 4                   207155  {'boost_from_average': True, 'boosting_type': ...
# 5                   487270  {'boost_from_average': True, 'boosting_type': ...
# 6                   287406  {'boost_from_average': True, 'boosting_type': ...
# 7                   209797  {'boost_from_average': True, 'boosting_type': ...
# 8                   247054  {'boost_from_average': True, 'boosting_type': ...
# 9                   280957  {'boost_from_average': True, 'boosting_type': ...
# 10                  490992  {'boost_from_average': True, 'boosting_type': ...
# 11                  145585  {'boost_from_average': True, 'boosting_type': ...
# 12                  185646  {'boost_from_average': True, 'boosting_type': ...
# 13                  100000  {'boost_from_average': True, 'boosting_type': ...
# 14                  100000  {'boost_from_average': True, 'boosting_type': ...
# 15                  333459  {'boost_from_average': True, 'boosting_type': ...
# 16                  408399  {'boost_from_average': True, 'boosting_type': ...
# 17                  314539  {'boost_from_average': True, 'boosting_type': ...
# 18                  402627  {'boost_from_average': True, 'boosting_type': ...
# 19                  479034  {'boost_from_average': True, 'boosting_type': ...
#
#    split0_test_score split1_test_score split2_test_score split3_test_score  \
# 0           0.714286          0.888889          0.625000          0.583333
# 1           0.555556          0.800000          0.666667          0.692308
# 2           0.454545          0.777778          0.615385          0.692308
# 3           0.611111          0.800000          0.642857          0.642857
# 4           0.625000          0.818182          0.666667          0.692308
# 5           0.461538          0.875000          0.642857          0.750000
# 6           0.583333          0.777778          0.642857          0.636364
# 7           0.636364          0.875000          0.600000          0.615385
# 8           0.666667          0.800000          0.666667          0.636364
# 9           0.500000          0.800000          0.538462          0.500000
# 10          0.533333          0.900000          0.615385          0.750000
# 11          0.571429          0.777778          0.666667          0.615385
# 12          0.562500          0.800000          0.625000          0.769231
# 13          0.600000          0.818182          0.687500          0.600000
# 14          0.600000          0.875000          0.555556          0.727273
# 15          0.615385          0.800000          0.571429          0.615385
# 16          0.500000          0.875000          0.642857          0.666667
# 17          0.538462          0.727273          0.600000          0.400000
# 18          0.545455          0.875000          0.642857          0.692308
# 19          0.647059          0.750000          0.666667          0.818182
#
#    split4_test_score mean_test_score std_test_score rank_test_score
# 0           0.750000        0.712302       0.106642               2
# 1           0.769231        0.696752       0.085761              12
# 2           0.750000        0.658003       0.115929              18
# 3           0.800000        0.699365       0.082982              11
# 4           0.727273        0.705886       0.065319               6
# 5           0.818182        0.709515       0.146129               4
# 6           0.800000        0.688066       0.085163              14
# 7           0.777778        0.700905       0.107591               9
# 8           0.727273        0.699394       0.058333              10
# 9           0.818182        0.631329       0.145933              19
# 10          0.750000        0.709744       0.126066               3
# 11          0.750000        0.676252       0.078142              16
# 12          0.750000        0.701346       0.091450               8
# 13          0.692308        0.679598       0.080126              15
# 14          0.750000        0.701566       0.113772               7
# 15          0.769231        0.674286       0.092018              17
# 16          0.857143        0.708333       0.140960               5
# 17          0.700000        0.593147       0.118111              20
# 18          0.727273        0.696578       0.108184              13
# 19          0.800000        0.736381       0.068939               1
#
# [20 rows x 28 columns]

# %%
df_base.iloc[:, 27:].head(60)
# Out:
#                            value30         value31         value33  \
# parameter
# acc_test                  0.660714        0.660714        0.589286
# acc_test1                 0.666667        0.666667             0.5
# acc_test2                 0.666667        0.666667        0.611111
# acc_test3                     0.65            0.65            0.65
# acc_train                 0.848315        0.853933        0.808989
# acc_val                        0.6             0.6        0.622222
# best_index                     0.0             0.0             4.0
# best_score                0.707756        0.712302        0.742908
# boost_from_average            True            True            True
# boosting_type                 gbdt            gbdt            gbdt
# class_weight                  None            None            None
# colsample_bytree          0.933539        0.933539        0.531354
# cv                               5               5               5
# f1score                   0.641509        0.641509        0.530612
# f1score1                       0.7             0.7        0.526316
# f1score2                  0.571429        0.571429        0.461538
# f1score3                  0.631579        0.631579        0.588235
# fn                            17.0            17.0            21.0
# fn1                            6.0             6.0             8.0
# fn2                            6.0             6.0             7.0
# fn3                            5.0             5.0             6.0
# force_col_wise                true            true            true
# fp                             2.0             2.0             2.0
# fp1                            0.0             0.0             1.0
# fp2                            0.0             0.0             0.0
# fp3                            2.0             2.0             1.0
# importance_type              split           split           split
# iterations                      10              10              10
# learning_rate             0.001661        0.001661        0.002525
# max_depth                       21              21              36
# metric              binary_logloss  binary_logloss  binary_logloss
# min_child_samples               32              32              30
# min_child_weight             0.001           0.001           0.001
# min_split_gain                 0.0             0.0             0.0
# n_estimators                  1013            1013            1047
# n_iter                         NaN             NaN             NaN
# n_jobs                          -1              -1              -1
# num_col                        110             110             110
# num_leaves                       8               8               8
# objective                   binary          binary          binary
# precision                 0.894737        0.894737        0.866667
# precision1                     1.0             1.0        0.833333
# precision2                     1.0             1.0             1.0
# precision3                    0.75            0.75        0.833333
# random_state                  None            None            None
# recall                         0.5             0.5        0.382353
# recall1                   0.538462        0.538462        0.384615
# recall2                        0.4             0.4             0.3
# recall3                   0.545455        0.545455        0.454545
# reg_alpha                        1             0.4             3.4
# reg_lambda                       1             0.6             1.0
# roc                       0.704545        0.704545        0.645722
# roc1                      0.769231        0.769231        0.592308
# roc2                           0.7             0.7            0.65
# roc3                      0.661616        0.661616        0.671717
# scale_pos_weight               NaN             NaN             0.7
# scoring                  precision       precision       precision
# silent                        warn            warn            warn
# subsample                 0.635775        0.635775        0.275208
# subsample_for_bin           131156          131156          494396
#
#                            value34         value35         value36  \
# parameter
# acc_test                  0.660714        0.660714        0.660714
# acc_test1                 0.666667        0.666667        0.666667
# acc_test2                 0.666667        0.666667        0.666667
# acc_test3                     0.65            0.65            0.65
# acc_train                 0.853933        0.853933        0.853933
# acc_val                        0.6             0.6             0.6
# best_index                     0.0             0.0             0.0
# best_score                0.712302        0.712302        0.712302
# boost_from_average            True            True            True
# boosting_type                 gbdt            gbdt            gbdt
# class_weight                  None            None            None
# colsample_bytree          0.933539        0.933539        0.933539
# cv                               5               5               5
# f1score                   0.641509        0.641509        0.641509
# f1score1                       0.7             0.7             0.7
# f1score2                  0.571429        0.571429        0.571429
# f1score3                  0.631579        0.631579        0.631579
# fn                            17.0            17.0            17.0
# fn1                            6.0             6.0             6.0
# fn2                            6.0             6.0             6.0
# fn3                            5.0             5.0             5.0
# force_col_wise                true            true            true
# fp                             2.0             2.0             2.0
# fp1                            0.0             0.0             0.0
# fp2                            0.0             0.0             0.0
# fp3                            2.0             2.0             2.0
# importance_type              split           split           split
# iterations                      10              15              17
# learning_rate             0.001661        0.001661        0.001661
# max_depth                       21              21              21
# metric              binary_logloss  binary_logloss  binary_logloss
# min_child_samples               32              32              32
# min_child_weight             0.001           0.001           0.001
# min_split_gain                 0.0             0.0             0.0
# n_estimators                  1013            1013            1013
# n_iter                         NaN             NaN             NaN
# n_jobs                          -1              -1              -1
# num_col                        110             110             110
# num_leaves                       8               8               8
# objective                   binary          binary          binary
# precision                 0.894737        0.894737        0.894737
# precision1                     1.0             1.0             1.0
# precision2                     1.0             1.0             1.0
# precision3                    0.75            0.75            0.75
# random_state                  None            None            None
# recall                         0.5             0.5             0.5
# recall1                   0.538462        0.538462        0.538462
# recall2                        0.4             0.4             0.4
# recall3                   0.545455        0.545455        0.545455
# reg_alpha                      0.4             0.4             0.4
# reg_lambda                     0.6             0.6             0.6
# roc                       0.704545        0.704545        0.704545
# roc1                      0.769231        0.769231        0.769231
# roc2                           0.7             0.7             0.7
# roc3                      0.661616        0.661616        0.661616
# scale_pos_weight               NaN             NaN             NaN
# scoring                  precision       precision       precision
# silent                        warn            warn            warn
# subsample                 0.635775        0.635775        0.635775
# subsample_for_bin           131156          131156          131156
#
#                            value37
# parameter
# acc_test                  0.607143
# acc_test1                      0.5
# acc_test2                 0.666667
# acc_test3                     0.65
# acc_train                 0.786517
# acc_val                   0.577778
# best_index                     2.0
# best_score                0.795051
# boost_from_average            True
# boosting_type                 goss
# class_weight                  None
# colsample_bytree          0.113811
# cv                               5
# f1score                   0.541667
# f1score1                  0.526316
# f1score2                  0.571429
# f1score3                  0.533333
# fn                            21.0
# fn1                            8.0
# fn2                            6.0
# fn3                            7.0
# force_col_wise                true
# fp                             1.0
# fp1                            1.0
# fp2                            0.0
# fp3                            0.0
# importance_type              split
# iterations                      10
# learning_rate               0.0007
# max_depth                       23
# metric              binary_logloss
# min_child_samples               33
# min_child_weight             0.001
# min_split_gain                 0.0
# n_estimators                  1190
# n_iter                         NaN
# n_jobs                          -1
# num_col                         60
# num_leaves                      10
# objective                   binary
# precision                 0.928571
# precision1                0.833333
# precision2                     1.0
# precision3                     1.0
# random_state                  None
# recall                    0.382353
# recall1                   0.384615
# recall2                        0.4
# recall3                   0.363636
# reg_alpha                      1.4
# reg_lambda                     0.8
# roc                       0.668449
# roc1                      0.592308
# roc2                           0.7
# roc3                      0.681818
# scale_pos_weight               NaN
# scoring                  precision
# silent                        warn
# subsample                 0.514456
# subsample_for_bin           278139

# %% [markdown]
# 베이시안으로 최적화하고, 영향이 없는 feature수를 줄이니 precision이 93%로 올라감.

# %%
# print(lgbmgs.best_estimator_)
print(lgbmBS.best_estimator_)
# Out:
# LGBMClassifier(boost_from_average=True, colsample_bytree=0.9335393188593556,
#                force_col_wise='true', learning_rate=0.0016612938916177552,
#                max_depth=21, metric='binary_logloss', min_child_samples=32,
#                n_estimators=1013, num_leaves=8, objective='binary',
#                reg_alpha=0.4, reg_lambda=0.6000000000000001,
#                subsample=0.6357746718688816, subsample_for_bin=131156,
#                verbose=1)

# %%
# model = lgbmgs.best_estimator_
model = lgbmBS.best_estimator_
feature_df = pd.DataFrame(model.booster_.feature_importance(importance_type='gain'), 
                      index=data.columns, columns=['importance']).sort_values(by='importance', 
                                                                              ascending=False)

# %%
len(feature_df)
# Out:
# 105

# %%
feature_df.tail(60)
# Out:
#                   importance
# wti_cr               3.98009
# splrcu_cr            3.67488
# ixfn_cr              3.62901
# vol_2                3.49061
# open_2               2.90575
# dxy_cr_2             2.58989
# ixtr_cr_2            0.00000
# nbi_cr_2             0.00000
# ixk_cr_2             0.00000
# ixis_cr_2            0.00000
# bkx_cr_2             0.00000
# close_2              0.00000
# bond_usa_3m_cr_2     0.00000
# splrci_cr_2          0.00000
# ixid_cr_2            0.00000
# vix_cr_2             0.00000
# ixbk_cr_2            0.00000
# wti_cr_2             0.00000
# spsy_cr_2            0.00000
# splrcm_cr_2          0.00000
# spny_cr_2            0.00000
# splrcl_cr_2          0.00000
# ixic_cr_2            0.00000
# spxhc_cr_2           0.00000
# splrcu_cr_2          0.00000
# ixfn_cr_2            0.00000
# retail_2             0.00000
# krw_cr_2             0.00000
# splrci_cr            0.00000
# institution_1        0.00000
# dji_cr               0.00000
# dji_f_cr             0.00000
# ixic_f_cr            0.00000
# bond_kor_10_cr       0.00000
# bond_kor_2_cr        0.00000
# kosdaq_cr            0.00000
# kospi_cr             0.00000
# krw_cr               0.00000
# spx_f_cr             0.00000
# spx_cr               0.00000
# bond_usa_10_cr       0.00000
# bond_usa_2_cr        0.00000
# spsy_cr              0.00000
# splrcs_cr            0.00000
# kosdaq_cr_2          0.00000
# splrcl_cr            0.00000
# splrcm_cr            0.00000
# ixbk_cr              0.00000
# ixis_cr              0.00000
# ixtr_cr              0.00000
# ixut_cr              0.00000
# open_1               0.00000
# close_1              0.00000
# vol_1                0.00000
# foreigner_2          0.00000
# insurance_2          0.00000
# dji_cr_2             0.00000
# dji_f_cr_2           0.00000
# ixic_f_cr_2          0.00000
# weekday              0.00000

# %%
new_col = list(feature_df.index[:55]) +  ['cr_00', 'cr_05', 'cr_10', 'cr_15', 'cr_20']

# %%
model.booster_.feature_importance(importance_type='gain')

# %%
model.booster_.feature_importance(importance_type='split')
# 큰 특징을 가지는 feature는 tree상위레벨에서 적게 사용됨.

# %%
# 사용된 column을 불러와서 신규column 지정하여 최적의 column 찾기에 사용
directory_for_ml = '../machine_learning/sec/'
fname = f'columns_ver1_0323_1535_72_0.74%.pkl'
f_name = directory_for_ml + fname
new_col = load_from_pickle(f_name)
new_col =  new_col[:61]+new_col[-5:] # 원하는 column 선정

# %% [markdown]
# 1. 정밀도, f1-score,
# 2. confusion matrix ((1,1), (2,2), 두개가 큰 비중이면 good, (1,2)은 틀린것을 맞다라고 구분, (2,1)은 맞는 것을 틀린 것이다 라고 결정하는 항목) 따라서
#     (2,2) -> (1,2) -> (1,1)로 확인하고. <br>
#     (1,2)가 크면 모델 제외 (정밀도(precision = TP / (TP + FP) )가 높아야 함. 낮으면 손해를 보게 됨.), <br>
#     재현율(Recall = TP / (TP + FN) ) 은 손해를 끼치지는 않음.
#
# <img src="https://raw.githubusercontent.com/fasthill/My-gist/main/data/picture/confusion_matrix.png" width="800"/> <br>

# %%
directory_for_ml = '../data/data_for_ml/expand_date/'
ss = pd.read_csv(directory_for_ml+'df_sec_sel.csv', index_col=0)

# %%
ss
